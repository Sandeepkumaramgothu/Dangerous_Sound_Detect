# %%
################################################################################
# 1) Mount Drive, Check GPU, and Check RAM
################################################################################

from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# Check GPU info
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if 'failed' in gpu_info:
    print('Not connected to a GPU')
else:
    print(gpu_info)
# Out:
# Tue Mar 25 20:41:02 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   45C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# Check RAM
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print(f'Your runtime has {ram_gb:.1f} gigabytes of available RAM\n')
if ram_gb < 20:
    print('Not using a high-RAM runtime.')
else:
    print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 13.6 gigabytes of available RAM
#
# Not using a high-RAM runtime.

# %%
################################################################################
# 2) Installs (if needed; adjust packages as necessary)
################################################################################

# !pip -qqq install pydub
# !pip -qqq install tensorboard
# !pip -qqq install visualkeras
# !pip -qqq install --upgrade keras
# !pip -qqq install --upgrade tensorflow
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 997.4/997.4 kB 14.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 17.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.9/644.9 MB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 20.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 53.9 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-text 2.18.1 requires tensorflow<2.19,>=2.18.0, but you have tensorflow 2.19.0 which is incompatible.
# tf-keras 2.18.0 requires tensorflow<2.19,>=2.18, but you have tensorflow 2.19.0 which is incompatible.

# %%
################################################################################
# 3) Imports
################################################################################

import os
import math
import numpy as np
import librosa
import json
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import pickle
import random

# Sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

# Audio
from IPython.display import Audio
from scipy.io import wavfile
import scipy
import soundfile as sf
from pydub import AudioSegment

# TensorFlow / Keras
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import plot_model
from tensorflow.keras import layers, models
from tensorflow.keras.layers import Flatten, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.applications.vgg19 import VGG19

# Visualization
import visualkeras

# %%
################################################################################
# 4) Define Base Directories
################################################################################

base_dir = '/content/drive/MyDrive/ASE_Dataset_Folder'
image_dir = os.path.join(base_dir, 'STFT_Images_1_Sec')
train_dir = os.path.join(image_dir, 'Train/Sounds')
test_dir = os.path.join(image_dir, 'Test/Sounds')

# Check if the directories exist
if not os.path.exists(train_dir):
    print(f"Train directory does not exist: {train_dir}")
if not os.path.exists(test_dir):
    print(f"Test directory does not exist: {test_dir}")

# List some files to confirm
print("Listing some files in train_dir:", os.listdir(train_dir)[:10])
print("Listing some files in test_dir:", os.listdir(test_dir)[:10])
# Out:
# Listing some files in train_dir: ['Explosion', 'Emergency_alarm', 'Gun_Shots', 'glass_breaking', 'thunderstorm', 'dog', 'wind']
# Listing some files in test_dir: ['Gun_Shots', 'Emergency_alarm', 'Explosion', 'dog', 'glass_breaking', 'thunderstorm', 'wind']

# %%
################################################################################
# 5) Data Generators
################################################################################

# You can adjust your augmentations here
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)
test_datagen = ImageDataGenerator(rescale=1./255)

batch_size = 32
height = 128
width = 128   # Typically you'd want your spectrogram images to have a consistent shape
channels = 3  # 3 if color images

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(height, width),
    batch_size=batch_size,
    class_mode='categorical'
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(height, width),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)

print(f"Found {train_generator.samples} images for training.")
print(f"Found {test_generator.samples} images for testing.")
# Out:
# Found 1020 images belonging to 7 classes.
# Found 443 images belonging to 7 classes.
# Found 1020 images for training.
# Found 443 images for testing.

# %%
################################################################################
# 6) Define a Custom F1 Metric (Optional)
################################################################################

import tensorflow.keras.backend as K
from tensorflow.keras.metrics import Precision, Recall

def f1_score_metric(y_true, y_pred):
    """Compute F1 using precision and recall at the batch level."""
    # Round predictions
    y_pred = K.round(y_pred)

    tp = K.sum(K.cast(y_true * y_pred, 'float'), axis=0)
    fp = K.sum(K.cast((1 - y_true) * y_pred, 'float'), axis=0)
    fn = K.sum(K.cast(y_true * (1 - y_pred), 'float'), axis=0)

    precision = tp / (tp + fp + K.epsilon())
    recall = tp / (tp + fn + K.epsilon())

    f1 = 2 * precision * recall / (precision + recall + K.epsilon())
    return K.mean(f1)

# %%
################################################################################
# 7) Load Pretrained VGG19 (with Frozen Layers)
################################################################################

# Include top=False means we remove the final dense layers,
# so we can replace them for our own classification.
vgg = VGG19(
    input_shape=(height, width, channels),
    weights="imagenet",
    include_top=False
)

# Freeze pretrained layers
for layer in vgg.layers:
    layer.trainable = False

x = Flatten()(vgg.output)
prediction = Dense(train_generator.num_classes, activation='softmax')(x)

model = Model(inputs=vgg.input, outputs=prediction)
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 128, 128, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, 128, 128, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, 128, 128, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, 64, 64, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv1 (Conv2D)                │ (None, 64, 64, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv2 (Conv2D)                │ (None, 64, 64, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_pool (MaxPooling2D)           │ (None, 32, 32, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv1 (Conv2D)                │ (None, 32, 32, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv2 (Conv2D)                │ (None, 32, 32, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv3 (Conv2D)                │ (None, 32, 32, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv4 (Conv2D)                │ (None, 32, 32, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_pool (MaxPooling2D)           │ (None, 16, 16, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv1 (Conv2D)                │ (None, 16, 16, 512)         │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv2 (Conv2D)                │ (None, 16, 16, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv3 (Conv2D)                │ (None, 16, 16, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv4 (Conv2D)                │ (None, 16, 16, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_pool (MaxPooling2D)           │ (None, 8, 8, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv1 (Conv2D)                │ (None, 8, 8, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv2 (Conv2D)                │ (None, 8, 8, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv3 (Conv2D)                │ (None, 8, 8, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv4 (Conv2D)                │ (None, 8, 8, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_pool (MaxPooling2D)           │ (None, 4, 4, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 8192)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 7)                   │          57,351 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 20,081,735 (76.61 MB)
#  Trainable params: 57,351 (224.03 KB)
#  Non-trainable params: 20,024,384 (76.39 MB)

# %%
################################################################################
# 8) Visualize Model
################################################################################

plot_model(model, to_file='model_structure.png', show_shapes=True, show_layer_names=True)
visualkeras.layered_view(model, legend=True)  # Only works in certain environments
# Out:
# /usr/local/lib/python3.11/dist-packages/visualkeras/layered.py:86: UserWarning: The legend_text_spacing_offset parameter is deprecated and will be removed in a future release.
#   warnings.warn("The legend_text_spacing_offset parameter is deprecated and will be removed in a future release.")
# <PIL.Image.Image image mode=RGBA size=1539x721>

# %%
# !pip install visualkeras --upgrade
import visualkeras
# Check for 'version' instead of '__version__'
try:
    print(visualkeras.version)
except AttributeError:
    print("Version information not found. Ensure 'visualkeras' is installed correctly.")
# Out:
# Requirement already satisfied: visualkeras in /usr/local/lib/python3.11/dist-packages (0.1.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from visualkeras) (11.1.0)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.11/dist-packages (from visualkeras) (2.0.2)
# Requirement already satisfied: aggdraw>=1.3.11 in /usr/local/lib/python3.11/dist-packages (from visualkeras) (1.3.19)
# Version information not found. Ensure 'visualkeras' is installed correctly.

# %%
################################################################################
# 9) Compile the Model
################################################################################

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=[
        'accuracy',
        Precision(name='precision'),
        Recall(name='recall'),
        f1_score_metric  # our custom F1
    ]
)

# %%
################################################################################
# 10) Fit the Model (Single Training Loop)
################################################################################

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    mode="min",
    patience=30,
    restore_best_weights=True
)

epochs = 100  # Adjust as needed

history = model.fit(
    train_generator,
    epochs=epochs,
    validation_data=test_generator,
    callbacks=[early_stopping],
    shuffle=True
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 390s 12s/step - accuracy: 0.2417 - f1_score_metric: 0.0431 - loss: 1.9696 - precision: 0.4581 - recall: 0.0654 - val_accuracy: 0.5282 - val_f1_score_metric: 0.0319 - val_loss: 1.3868 - val_precision: 0.9048 - val_recall: 0.1716
# Epoch 2/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 743ms/step - accuracy: 0.5062 - f1_score_metric: 0.1702 - loss: 1.3455 - precision: 0.7904 - recall: 0.2446 - val_accuracy: 0.5395 - val_f1_score_metric: 0.0606 - val_loss: 1.1611 - val_precision: 0.8375 - val_recall: 0.3025
# Epoch 3/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 744ms/step - accuracy: 0.5904 - f1_score_metric: 0.2900 - loss: 1.1552 - precision: 0.8162 - recall: 0.3124 - val_accuracy: 0.5779 - val_f1_score_metric: 0.0675 - val_loss: 1.0845 - val_precision: 0.7290 - val_recall: 0.3521
# Epoch 4/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 27s 861ms/step - accuracy: 0.6261 - f1_score_metric: 0.3719 - loss: 1.0309 - precision: 0.8190 - recall: 0.3819 - val_accuracy: 0.6343 - val_f1_score_metric: 0.0950 - val_loss: 1.0026 - val_precision: 0.8598 - val_recall: 0.4153
# Epoch 5/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 736ms/step - accuracy: 0.6083 - f1_score_metric: 0.4128 - loss: 0.9956 - precision: 0.7809 - recall: 0.4224 - val_accuracy: 0.7020 - val_f1_score_metric: 0.1025 - val_loss: 0.9117 - val_precision: 0.8508 - val_recall: 0.4763
# Epoch 6/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 711ms/step - accuracy: 0.7006 - f1_score_metric: 0.5064 - loss: 0.8483 - precision: 0.8633 - recall: 0.4860 - val_accuracy: 0.7043 - val_f1_score_metric: 0.1147 - val_loss: 0.8683 - val_precision: 0.8707 - val_recall: 0.5169
# Epoch 7/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 735ms/step - accuracy: 0.6992 - f1_score_metric: 0.5231 - loss: 0.8498 - precision: 0.8577 - recall: 0.4917 - val_accuracy: 0.6682 - val_f1_score_metric: 0.1147 - val_loss: 0.9157 - val_precision: 0.7732 - val_recall: 0.5079
# Epoch 8/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 731ms/step - accuracy: 0.6755 - f1_score_metric: 0.5378 - loss: 0.8477 - precision: 0.8457 - recall: 0.5158 - val_accuracy: 0.7223 - val_f1_score_metric: 0.1146 - val_loss: 0.8393 - val_precision: 0.8151 - val_recall: 0.5372
# Epoch 9/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 742ms/step - accuracy: 0.7400 - f1_score_metric: 0.5731 - loss: 0.7797 - precision: 0.8655 - recall: 0.5587 - val_accuracy: 0.7517 - val_f1_score_metric: 0.1233 - val_loss: 0.8118 - val_precision: 0.8344 - val_recall: 0.5801
# Epoch 10/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 732ms/step - accuracy: 0.7423 - f1_score_metric: 0.5716 - loss: 0.7632 - precision: 0.8706 - recall: 0.5560 - val_accuracy: 0.7201 - val_f1_score_metric: 0.1340 - val_loss: 0.8375 - val_precision: 0.8393 - val_recall: 0.5779
# Epoch 11/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 27s 859ms/step - accuracy: 0.7387 - f1_score_metric: 0.6185 - loss: 0.7355 - precision: 0.8480 - recall: 0.6039 - val_accuracy: 0.6524 - val_f1_score_metric: 0.1213 - val_loss: 0.9473 - val_precision: 0.7569 - val_recall: 0.5553
# Epoch 12/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 27s 863ms/step - accuracy: 0.7424 - f1_score_metric: 0.6226 - loss: 0.7277 - precision: 0.8329 - recall: 0.6093 - val_accuracy: 0.7630 - val_f1_score_metric: 0.1289 - val_loss: 0.7855 - val_precision: 0.8303 - val_recall: 0.6185
# Epoch 13/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 734ms/step - accuracy: 0.7215 - f1_score_metric: 0.6071 - loss: 0.7079 - precision: 0.8494 - recall: 0.6226 - val_accuracy: 0.7359 - val_f1_score_metric: 0.1391 - val_loss: 0.7840 - val_precision: 0.8498 - val_recall: 0.6388
# Epoch 14/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 703ms/step - accuracy: 0.7747 - f1_score_metric: 0.6935 - loss: 0.6621 - precision: 0.8662 - recall: 0.6459 - val_accuracy: 0.7630 - val_f1_score_metric: 0.1413 - val_loss: 0.7385 - val_precision: 0.8343 - val_recall: 0.6366
# Epoch 15/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 738ms/step - accuracy: 0.8005 - f1_score_metric: 0.6790 - loss: 0.6350 - precision: 0.8745 - recall: 0.6634 - val_accuracy: 0.7652 - val_f1_score_metric: 0.1315 - val_loss: 0.7657 - val_precision: 0.8223 - val_recall: 0.6479
# Epoch 16/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 732ms/step - accuracy: 0.7882 - f1_score_metric: 0.6851 - loss: 0.6252 - precision: 0.8864 - recall: 0.6696 - val_accuracy: 0.7427 - val_f1_score_metric: 0.1288 - val_loss: 0.7673 - val_precision: 0.8230 - val_recall: 0.6298
# Epoch 17/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 708ms/step - accuracy: 0.7305 - f1_score_metric: 0.6464 - loss: 0.7008 - precision: 0.8404 - recall: 0.6374 - val_accuracy: 0.7517 - val_f1_score_metric: 0.1374 - val_loss: 0.7661 - val_precision: 0.8067 - val_recall: 0.6501
# Epoch 18/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 42s 729ms/step - accuracy: 0.7716 - f1_score_metric: 0.6589 - loss: 0.6057 - precision: 0.8744 - recall: 0.6733 - val_accuracy: 0.7404 - val_f1_score_metric: 0.1272 - val_loss: 0.7321 - val_precision: 0.8384 - val_recall: 0.6208
# Epoch 19/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 702ms/step - accuracy: 0.7846 - f1_score_metric: 0.7337 - loss: 0.6116 - precision: 0.8885 - recall: 0.6931 - val_accuracy: 0.7901 - val_f1_score_metric: 0.1472 - val_loss: 0.6813 - val_precision: 0.8455 - val_recall: 0.6795
# Epoch 20/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 42s 729ms/step - accuracy: 0.8024 - f1_score_metric: 0.7037 - loss: 0.6022 - precision: 0.8796 - recall: 0.6958 - val_accuracy: 0.7675 - val_f1_score_metric: 0.1345 - val_loss: 0.7131 - val_precision: 0.8377 - val_recall: 0.6524
# Epoch 21/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 712ms/step - accuracy: 0.7862 - f1_score_metric: 0.7124 - loss: 0.6019 - precision: 0.8527 - recall: 0.6987 - val_accuracy: 0.7111 - val_f1_score_metric: 0.1345 - val_loss: 0.7746 - val_precision: 0.7885 - val_recall: 0.6479
# Epoch 22/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 45s 853ms/step - accuracy: 0.8010 - f1_score_metric: 0.7143 - loss: 0.5883 - precision: 0.8782 - recall: 0.7261 - val_accuracy: 0.7630 - val_f1_score_metric: 0.1414 - val_loss: 0.7045 - val_precision: 0.8235 - val_recall: 0.6637
# Epoch 23/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 739ms/step - accuracy: 0.8286 - f1_score_metric: 0.7447 - loss: 0.5304 - precision: 0.8931 - recall: 0.7438 - val_accuracy: 0.7359 - val_f1_score_metric: 0.1276 - val_loss: 0.7872 - val_precision: 0.7994 - val_recall: 0.6479
# Epoch 24/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 703ms/step - accuracy: 0.8044 - f1_score_metric: 0.7100 - loss: 0.5922 - precision: 0.8654 - recall: 0.7024 - val_accuracy: 0.7540 - val_f1_score_metric: 0.1509 - val_loss: 0.6585 - val_precision: 0.8436 - val_recall: 0.6817
# Epoch 25/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 728ms/step - accuracy: 0.8050 - f1_score_metric: 0.7591 - loss: 0.5624 - precision: 0.8820 - recall: 0.7392 - val_accuracy: 0.7020 - val_f1_score_metric: 0.1393 - val_loss: 0.7940 - val_precision: 0.7889 - val_recall: 0.6411
# Epoch 26/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 729ms/step - accuracy: 0.7811 - f1_score_metric: 0.6659 - loss: 0.5844 - precision: 0.8538 - recall: 0.6927 - val_accuracy: 0.7449 - val_f1_score_metric: 0.1438 - val_loss: 0.7087 - val_precision: 0.8320 - val_recall: 0.6817
# Epoch 27/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 27s 857ms/step - accuracy: 0.8063 - f1_score_metric: 0.7042 - loss: 0.5669 - precision: 0.8551 - recall: 0.7158 - val_accuracy: 0.7517 - val_f1_score_metric: 0.1397 - val_loss: 0.7479 - val_precision: 0.8217 - val_recall: 0.6659
# Epoch 28/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 27s 856ms/step - accuracy: 0.7970 - f1_score_metric: 0.7123 - loss: 0.5429 - precision: 0.8666 - recall: 0.7266 - val_accuracy: 0.6953 - val_f1_score_metric: 0.1398 - val_loss: 0.8074 - val_precision: 0.7751 - val_recall: 0.6456
# Epoch 29/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 724ms/step - accuracy: 0.8056 - f1_score_metric: 0.7447 - loss: 0.5647 - precision: 0.8687 - recall: 0.7326 - val_accuracy: 0.7269 - val_f1_score_metric: 0.1409 - val_loss: 0.7164 - val_precision: 0.8146 - val_recall: 0.6546
# Epoch 30/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 702ms/step - accuracy: 0.8087 - f1_score_metric: 0.7366 - loss: 0.5261 - precision: 0.8718 - recall: 0.7271 - val_accuracy: 0.7698 - val_f1_score_metric: 0.1500 - val_loss: 0.6386 - val_precision: 0.8476 - val_recall: 0.6907
# Epoch 31/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 731ms/step - accuracy: 0.8350 - f1_score_metric: 0.7455 - loss: 0.4874 - precision: 0.8976 - recall: 0.7471 - val_accuracy: 0.7923 - val_f1_score_metric: 0.1469 - val_loss: 0.5966 - val_precision: 0.8364 - val_recall: 0.7269
# Epoch 32/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 719ms/step - accuracy: 0.8485 - f1_score_metric: 0.7661 - loss: 0.4775 - precision: 0.8916 - recall: 0.7708 - val_accuracy: 0.7901 - val_f1_score_metric: 0.1464 - val_loss: 0.6907 - val_precision: 0.8387 - val_recall: 0.7043
# Epoch 33/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 718ms/step - accuracy: 0.8102 - f1_score_metric: 0.7096 - loss: 0.5273 - precision: 0.8654 - recall: 0.7145 - val_accuracy: 0.7878 - val_f1_score_metric: 0.1504 - val_loss: 0.6192 - val_precision: 0.8560 - val_recall: 0.6975
# Epoch 34/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 45s 848ms/step - accuracy: 0.8231 - f1_score_metric: 0.7574 - loss: 0.4925 - precision: 0.8893 - recall: 0.7724 - val_accuracy: 0.7607 - val_f1_score_metric: 0.1453 - val_loss: 0.7150 - val_precision: 0.8221 - val_recall: 0.6885
# Epoch 35/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 727ms/step - accuracy: 0.7981 - f1_score_metric: 0.7353 - loss: 0.5262 - precision: 0.8627 - recall: 0.7593 - val_accuracy: 0.7856 - val_f1_score_metric: 0.1444 - val_loss: 0.6941 - val_precision: 0.8369 - val_recall: 0.7065
# Epoch 36/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 27s 850ms/step - accuracy: 0.8384 - f1_score_metric: 0.7435 - loss: 0.4949 - precision: 0.9019 - recall: 0.7577 - val_accuracy: 0.7585 - val_f1_score_metric: 0.1424 - val_loss: 0.7393 - val_precision: 0.8226 - val_recall: 0.6907
# Epoch 37/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 37s 720ms/step - accuracy: 0.8425 - f1_score_metric: 0.7652 - loss: 0.4679 - precision: 0.8857 - recall: 0.7710 - val_accuracy: 0.7427 - val_f1_score_metric: 0.1378 - val_loss: 0.7000 - val_precision: 0.8110 - val_recall: 0.6975
# Epoch 38/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 707ms/step - accuracy: 0.8313 - f1_score_metric: 0.7879 - loss: 0.4613 - precision: 0.9066 - recall: 0.7690 - val_accuracy: 0.7946 - val_f1_score_metric: 0.1501 - val_loss: 0.6172 - val_precision: 0.8602 - val_recall: 0.7359
# Epoch 39/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 708ms/step - accuracy: 0.8491 - f1_score_metric: 0.7895 - loss: 0.4613 - precision: 0.9038 - recall: 0.7773 - val_accuracy: 0.7630 - val_f1_score_metric: 0.1424 - val_loss: 0.7206 - val_precision: 0.8237 - val_recall: 0.7065
# Epoch 40/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 720ms/step - accuracy: 0.8398 - f1_score_metric: 0.7758 - loss: 0.4623 - precision: 0.9033 - recall: 0.7885 - val_accuracy: 0.7562 - val_f1_score_metric: 0.1413 - val_loss: 0.7385 - val_precision: 0.7959 - val_recall: 0.6953
# Epoch 41/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 735ms/step - accuracy: 0.8224 - f1_score_metric: 0.7657 - loss: 0.4713 - precision: 0.8867 - recall: 0.7828 - val_accuracy: 0.8036 - val_f1_score_metric: 0.1571 - val_loss: 0.5742 - val_precision: 0.8740 - val_recall: 0.7517
# Epoch 42/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 27s 859ms/step - accuracy: 0.8540 - f1_score_metric: 0.7799 - loss: 0.4461 - precision: 0.9152 - recall: 0.8003 - val_accuracy: 0.8172 - val_f1_score_metric: 0.1555 - val_loss: 0.5704 - val_precision: 0.8700 - val_recall: 0.7404
# Epoch 43/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 711ms/step - accuracy: 0.8393 - f1_score_metric: 0.7825 - loss: 0.4616 - precision: 0.8959 - recall: 0.7730 - val_accuracy: 0.7607 - val_f1_score_metric: 0.1395 - val_loss: 0.7361 - val_precision: 0.8123 - val_recall: 0.6840
# Epoch 44/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 691ms/step - accuracy: 0.8398 - f1_score_metric: 0.7702 - loss: 0.4303 - precision: 0.8852 - recall: 0.7785 - val_accuracy: 0.7991 - val_f1_score_metric: 0.1513 - val_loss: 0.5719 - val_precision: 0.8590 - val_recall: 0.7291
# Epoch 45/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 728ms/step - accuracy: 0.8580 - f1_score_metric: 0.8114 - loss: 0.4166 - precision: 0.9123 - recall: 0.8111 - val_accuracy: 0.8036 - val_f1_score_metric: 0.1510 - val_loss: 0.5812 - val_precision: 0.8542 - val_recall: 0.7404
# Epoch 46/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 722ms/step - accuracy: 0.8552 - f1_score_metric: 0.7998 - loss: 0.4255 - precision: 0.9116 - recall: 0.7877 - val_accuracy: 0.7923 - val_f1_score_metric: 0.1470 - val_loss: 0.6593 - val_precision: 0.8368 - val_recall: 0.7178
# Epoch 47/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 724ms/step - accuracy: 0.8593 - f1_score_metric: 0.7920 - loss: 0.4222 - precision: 0.9214 - recall: 0.8059 - val_accuracy: 0.7743 - val_f1_score_metric: 0.1487 - val_loss: 0.6189 - val_precision: 0.8403 - val_recall: 0.7246
# Epoch 48/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 717ms/step - accuracy: 0.8286 - f1_score_metric: 0.7611 - loss: 0.4934 - precision: 0.8854 - recall: 0.7794 - val_accuracy: 0.7833 - val_f1_score_metric: 0.1491 - val_loss: 0.6597 - val_precision: 0.8184 - val_recall: 0.7223
# Epoch 49/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 702ms/step - accuracy: 0.8364 - f1_score_metric: 0.7715 - loss: 0.4600 - precision: 0.8821 - recall: 0.7786 - val_accuracy: 0.8059 - val_f1_score_metric: 0.1590 - val_loss: 0.5533 - val_precision: 0.8692 - val_recall: 0.7652
# Epoch 50/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 716ms/step - accuracy: 0.8402 - f1_score_metric: 0.7763 - loss: 0.4491 - precision: 0.8816 - recall: 0.7792 - val_accuracy: 0.8149 - val_f1_score_metric: 0.1512 - val_loss: 0.5967 - val_precision: 0.8601 - val_recall: 0.7494
# Epoch 51/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 723ms/step - accuracy: 0.8750 - f1_score_metric: 0.7946 - loss: 0.4050 - precision: 0.9058 - recall: 0.8106 - val_accuracy: 0.7607 - val_f1_score_metric: 0.1436 - val_loss: 0.7112 - val_precision: 0.8260 - val_recall: 0.7178
# Epoch 52/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 723ms/step - accuracy: 0.8493 - f1_score_metric: 0.7880 - loss: 0.4357 - precision: 0.8984 - recall: 0.7913 - val_accuracy: 0.8104 - val_f1_score_metric: 0.1501 - val_loss: 0.6008 - val_precision: 0.8426 - val_recall: 0.7494
# Epoch 53/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 45s 858ms/step - accuracy: 0.8522 - f1_score_metric: 0.7848 - loss: 0.4568 - precision: 0.8976 - recall: 0.7994 - val_accuracy: 0.7946 - val_f1_score_metric: 0.1498 - val_loss: 0.5809 - val_precision: 0.8438 - val_recall: 0.7314
# Epoch 54/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 27s 859ms/step - accuracy: 0.8288 - f1_score_metric: 0.7440 - loss: 0.4469 - precision: 0.8735 - recall: 0.7599 - val_accuracy: 0.7923 - val_f1_score_metric: 0.1587 - val_loss: 0.5790 - val_precision: 0.8428 - val_recall: 0.7381
# Epoch 55/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 729ms/step - accuracy: 0.8720 - f1_score_metric: 0.8245 - loss: 0.4191 - precision: 0.9170 - recall: 0.8222 - val_accuracy: 0.7743 - val_f1_score_metric: 0.1482 - val_loss: 0.5801 - val_precision: 0.8402 - val_recall: 0.7359
# Epoch 56/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 719ms/step - accuracy: 0.8582 - f1_score_metric: 0.8064 - loss: 0.4077 - precision: 0.8931 - recall: 0.8144 - val_accuracy: 0.7991 - val_f1_score_metric: 0.1528 - val_loss: 0.5662 - val_precision: 0.8601 - val_recall: 0.7494
# Epoch 57/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 699ms/step - accuracy: 0.8598 - f1_score_metric: 0.7838 - loss: 0.4018 - precision: 0.8914 - recall: 0.7919 - val_accuracy: 0.7856 - val_f1_score_metric: 0.1483 - val_loss: 0.6366 - val_precision: 0.8272 - val_recall: 0.7133
# Epoch 58/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 42s 719ms/step - accuracy: 0.8557 - f1_score_metric: 0.8001 - loss: 0.4196 - precision: 0.8958 - recall: 0.8081 - val_accuracy: 0.7788 - val_f1_score_metric: 0.1500 - val_loss: 0.5936 - val_precision: 0.8432 - val_recall: 0.7404
# Epoch 59/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 27s 855ms/step - accuracy: 0.8677 - f1_score_metric: 0.7942 - loss: 0.4017 - precision: 0.9115 - recall: 0.8094 - val_accuracy: 0.7946 - val_f1_score_metric: 0.1530 - val_loss: 0.6170 - val_precision: 0.8414 - val_recall: 0.7427
# Epoch 60/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 711ms/step - accuracy: 0.8774 - f1_score_metric: 0.8176 - loss: 0.3900 - precision: 0.9149 - recall: 0.8154 - val_accuracy: 0.7991 - val_f1_score_metric: 0.1526 - val_loss: 0.5957 - val_precision: 0.8420 - val_recall: 0.7698
# Epoch 61/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 725ms/step - accuracy: 0.8598 - f1_score_metric: 0.7799 - loss: 0.4328 - precision: 0.9034 - recall: 0.7996 - val_accuracy: 0.7968 - val_f1_score_metric: 0.1478 - val_loss: 0.6399 - val_precision: 0.8286 - val_recall: 0.7314
# Epoch 62/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 27s 855ms/step - accuracy: 0.8528 - f1_score_metric: 0.7886 - loss: 0.3903 - precision: 0.9015 - recall: 0.8023 - val_accuracy: 0.7856 - val_f1_score_metric: 0.1533 - val_loss: 0.6015 - val_precision: 0.8467 - val_recall: 0.7607
# Epoch 63/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 730ms/step - accuracy: 0.8760 - f1_score_metric: 0.8194 - loss: 0.3733 - precision: 0.9212 - recall: 0.8292 - val_accuracy: 0.8036 - val_f1_score_metric: 0.1523 - val_loss: 0.6026 - val_precision: 0.8492 - val_recall: 0.7630
# Epoch 64/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 701ms/step - accuracy: 0.8691 - f1_score_metric: 0.8310 - loss: 0.4068 - precision: 0.9237 - recall: 0.8205 - val_accuracy: 0.7878 - val_f1_score_metric: 0.1515 - val_loss: 0.5905 - val_precision: 0.8388 - val_recall: 0.7517
# Epoch 65/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 731ms/step - accuracy: 0.8872 - f1_score_metric: 0.8392 - loss: 0.3644 - precision: 0.9261 - recall: 0.8445 - val_accuracy: 0.7427 - val_f1_score_metric: 0.1377 - val_loss: 0.7437 - val_precision: 0.7797 - val_recall: 0.6953
# Epoch 66/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 731ms/step - accuracy: 0.8531 - f1_score_metric: 0.7856 - loss: 0.4182 - precision: 0.8887 - recall: 0.8111 - val_accuracy: 0.8036 - val_f1_score_metric: 0.1520 - val_loss: 0.6131 - val_precision: 0.8421 - val_recall: 0.7585
# Epoch 67/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 729ms/step - accuracy: 0.8908 - f1_score_metric: 0.8400 - loss: 0.3418 - precision: 0.9382 - recall: 0.8542 - val_accuracy: 0.8284 - val_f1_score_metric: 0.1585 - val_loss: 0.5581 - val_precision: 0.8582 - val_recall: 0.7652
# Epoch 68/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 706ms/step - accuracy: 0.8607 - f1_score_metric: 0.8032 - loss: 0.3806 - precision: 0.9226 - recall: 0.8222 - val_accuracy: 0.7856 - val_f1_score_metric: 0.1504 - val_loss: 0.6093 - val_precision: 0.8313 - val_recall: 0.7562
# Epoch 69/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 734ms/step - accuracy: 0.8668 - f1_score_metric: 0.8186 - loss: 0.4098 - precision: 0.9135 - recall: 0.8185 - val_accuracy: 0.7901 - val_f1_score_metric: 0.1506 - val_loss: 0.6130 - val_precision: 0.8392 - val_recall: 0.7540
# Epoch 70/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 722ms/step - accuracy: 0.8542 - f1_score_metric: 0.8145 - loss: 0.4220 - precision: 0.9082 - recall: 0.8126 - val_accuracy: 0.8194 - val_f1_score_metric: 0.1560 - val_loss: 0.5285 - val_precision: 0.8643 - val_recall: 0.7765
# Epoch 71/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 711ms/step - accuracy: 0.8407 - f1_score_metric: 0.7784 - loss: 0.4240 - precision: 0.8740 - recall: 0.7972 - val_accuracy: 0.7856 - val_f1_score_metric: 0.1431 - val_loss: 0.5997 - val_precision: 0.8429 - val_recall: 0.7269
# Epoch 72/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 721ms/step - accuracy: 0.8641 - f1_score_metric: 0.8255 - loss: 0.4147 - precision: 0.9121 - recall: 0.8168 - val_accuracy: 0.8104 - val_f1_score_metric: 0.1556 - val_loss: 0.5474 - val_precision: 0.8579 - val_recall: 0.7765
# Epoch 73/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 713ms/step - accuracy: 0.8649 - f1_score_metric: 0.8212 - loss: 0.3647 - precision: 0.9278 - recall: 0.8188 - val_accuracy: 0.8284 - val_f1_score_metric: 0.1623 - val_loss: 0.5042 - val_precision: 0.8762 - val_recall: 0.7991
# Epoch 74/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 719ms/step - accuracy: 0.8642 - f1_score_metric: 0.7866 - loss: 0.4073 - precision: 0.9063 - recall: 0.8184 - val_accuracy: 0.8149 - val_f1_score_metric: 0.1559 - val_loss: 0.5398 - val_precision: 0.8622 - val_recall: 0.7765
# Epoch 75/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 27s 849ms/step - accuracy: 0.8955 - f1_score_metric: 0.8613 - loss: 0.3333 - precision: 0.9352 - recall: 0.8523 - val_accuracy: 0.8239 - val_f1_score_metric: 0.1613 - val_loss: 0.5155 - val_precision: 0.8603 - val_recall: 0.7923
# Epoch 76/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 715ms/step - accuracy: 0.8482 - f1_score_metric: 0.8161 - loss: 0.3778 - precision: 0.8912 - recall: 0.8180 - val_accuracy: 0.7923 - val_f1_score_metric: 0.1524 - val_loss: 0.5876 - val_precision: 0.8425 - val_recall: 0.7607
# Epoch 77/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 717ms/step - accuracy: 0.8769 - f1_score_metric: 0.8352 - loss: 0.3641 - precision: 0.9147 - recall: 0.8373 - val_accuracy: 0.8149 - val_f1_score_metric: 0.1552 - val_loss: 0.5359 - val_precision: 0.8561 - val_recall: 0.7788
# Epoch 78/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 708ms/step - accuracy: 0.8966 - f1_score_metric: 0.8380 - loss: 0.3400 - precision: 0.9284 - recall: 0.8517 - val_accuracy: 0.8284 - val_f1_score_metric: 0.1642 - val_loss: 0.5015 - val_precision: 0.8750 - val_recall: 0.8059
# Epoch 79/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 711ms/step - accuracy: 0.8761 - f1_score_metric: 0.8488 - loss: 0.3511 - precision: 0.9258 - recall: 0.8354 - val_accuracy: 0.8104 - val_f1_score_metric: 0.1557 - val_loss: 0.5813 - val_precision: 0.8575 - val_recall: 0.7743
# Epoch 80/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 728ms/step - accuracy: 0.8805 - f1_score_metric: 0.8182 - loss: 0.3497 - precision: 0.9151 - recall: 0.8317 - val_accuracy: 0.7630 - val_f1_score_metric: 0.1431 - val_loss: 0.6697 - val_precision: 0.8060 - val_recall: 0.7314
# Epoch 81/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 717ms/step - accuracy: 0.8742 - f1_score_metric: 0.8350 - loss: 0.3576 - precision: 0.9111 - recall: 0.8403 - val_accuracy: 0.7156 - val_f1_score_metric: 0.1343 - val_loss: 0.8369 - val_precision: 0.7557 - val_recall: 0.6772
# Epoch 82/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 695ms/step - accuracy: 0.8629 - f1_score_metric: 0.8074 - loss: 0.3998 - precision: 0.8928 - recall: 0.8265 - val_accuracy: 0.7720 - val_f1_score_metric: 0.1446 - val_loss: 0.6770 - val_precision: 0.8201 - val_recall: 0.7201
# Epoch 83/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 710ms/step - accuracy: 0.8967 - f1_score_metric: 0.8737 - loss: 0.3354 - precision: 0.9366 - recall: 0.8592 - val_accuracy: 0.7991 - val_f1_score_metric: 0.1542 - val_loss: 0.5562 - val_precision: 0.8568 - val_recall: 0.7698
# Epoch 84/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 721ms/step - accuracy: 0.8779 - f1_score_metric: 0.8365 - loss: 0.3405 - precision: 0.9289 - recall: 0.8406 - val_accuracy: 0.8194 - val_f1_score_metric: 0.1572 - val_loss: 0.5226 - val_precision: 0.8526 - val_recall: 0.7833
# Epoch 85/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 729ms/step - accuracy: 0.9019 - f1_score_metric: 0.8664 - loss: 0.3236 - precision: 0.9298 - recall: 0.8589 - val_accuracy: 0.8081 - val_f1_score_metric: 0.1565 - val_loss: 0.5649 - val_precision: 0.8410 - val_recall: 0.7878
# Epoch 86/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 698ms/step - accuracy: 0.8617 - f1_score_metric: 0.7868 - loss: 0.3956 - precision: 0.8878 - recall: 0.8268 - val_accuracy: 0.7946 - val_f1_score_metric: 0.1540 - val_loss: 0.5902 - val_precision: 0.8462 - val_recall: 0.7698
# Epoch 87/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 733ms/step - accuracy: 0.8727 - f1_score_metric: 0.8104 - loss: 0.3736 - precision: 0.9119 - recall: 0.8185 - val_accuracy: 0.8126 - val_f1_score_metric: 0.1592 - val_loss: 0.5677 - val_precision: 0.8486 - val_recall: 0.7968
# Epoch 88/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 725ms/step - accuracy: 0.8930 - f1_score_metric: 0.8832 - loss: 0.3056 - precision: 0.9316 - recall: 0.8738 - val_accuracy: 0.8172 - val_f1_score_metric: 0.1607 - val_loss: 0.5153 - val_precision: 0.8657 - val_recall: 0.7856
# Epoch 89/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 715ms/step - accuracy: 0.8857 - f1_score_metric: 0.8438 - loss: 0.3402 - precision: 0.9254 - recall: 0.8416 - val_accuracy: 0.8262 - val_f1_score_metric: 0.1665 - val_loss: 0.4974 - val_precision: 0.8696 - val_recall: 0.8126
# Epoch 90/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 716ms/step - accuracy: 0.8869 - f1_score_metric: 0.8083 - loss: 0.3641 - precision: 0.9120 - recall: 0.8474 - val_accuracy: 0.8284 - val_f1_score_metric: 0.1594 - val_loss: 0.5219 - val_precision: 0.8603 - val_recall: 0.7788
# Epoch 91/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 27s 849ms/step - accuracy: 0.8845 - f1_score_metric: 0.8302 - loss: 0.3494 - precision: 0.9232 - recall: 0.8464 - val_accuracy: 0.7991 - val_f1_score_metric: 0.1552 - val_loss: 0.5883 - val_precision: 0.8532 - val_recall: 0.7743
# Epoch 92/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 27s 860ms/step - accuracy: 0.8828 - f1_score_metric: 0.8421 - loss: 0.3216 - precision: 0.9194 - recall: 0.8564 - val_accuracy: 0.7991 - val_f1_score_metric: 0.1565 - val_loss: 0.5752 - val_precision: 0.8374 - val_recall: 0.7788
# Epoch 93/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 723ms/step - accuracy: 0.8665 - f1_score_metric: 0.7973 - loss: 0.3601 - precision: 0.9095 - recall: 0.8276 - val_accuracy: 0.7923 - val_f1_score_metric: 0.1520 - val_loss: 0.5790 - val_precision: 0.8313 - val_recall: 0.7562
# Epoch 94/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 701ms/step - accuracy: 0.8933 - f1_score_metric: 0.8305 - loss: 0.3364 - precision: 0.9235 - recall: 0.8537 - val_accuracy: 0.8284 - val_f1_score_metric: 0.1655 - val_loss: 0.4962 - val_precision: 0.8686 - val_recall: 0.8059
# Epoch 95/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 718ms/step - accuracy: 0.8849 - f1_score_metric: 0.8508 - loss: 0.3416 - precision: 0.9059 - recall: 0.8652 - val_accuracy: 0.8126 - val_f1_score_metric: 0.1536 - val_loss: 0.5771 - val_precision: 0.8329 - val_recall: 0.7652
# Epoch 96/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 692ms/step - accuracy: 0.8603 - f1_score_metric: 0.8134 - loss: 0.3760 - precision: 0.9094 - recall: 0.8229 - val_accuracy: 0.8126 - val_f1_score_metric: 0.1575 - val_loss: 0.5341 - val_precision: 0.8586 - val_recall: 0.7810
# Epoch 97/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 721ms/step - accuracy: 0.8808 - f1_score_metric: 0.8326 - loss: 0.3418 - precision: 0.9254 - recall: 0.8402 - val_accuracy: 0.8014 - val_f1_score_metric: 0.1581 - val_loss: 0.5359 - val_precision: 0.8452 - val_recall: 0.7765
# Epoch 98/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 721ms/step - accuracy: 0.8889 - f1_score_metric: 0.8352 - loss: 0.3247 - precision: 0.9221 - recall: 0.8512 - val_accuracy: 0.8014 - val_f1_score_metric: 0.1537 - val_loss: 0.5962 - val_precision: 0.8467 - val_recall: 0.7607
# Epoch 99/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 27s 852ms/step - accuracy: 0.8953 - f1_score_metric: 0.8311 - loss: 0.3220 - precision: 0.9261 - recall: 0.8526 - val_accuracy: 0.8126 - val_f1_score_metric: 0.1560 - val_loss: 0.5038 - val_precision: 0.8526 - val_recall: 0.7833
# Epoch 100/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 721ms/step - accuracy: 0.8881 - f1_score_metric: 0.8366 - loss: 0.3146 - precision: 0.9350 - recall: 0.8479 - val_accuracy: 0.8126 - val_f1_score_metric: 0.1575 - val_loss: 0.5165 - val_precision: 0.8596 - val_recall: 0.7878

# %%
################################################################################
# 11) Evaluate & Save
################################################################################

# Evaluate on the test set
scores = model.evaluate(test_generator, verbose=1)
print(f"Test Loss: {scores[0]:.4f}")
print(f"Test Accuracy: {scores[1]:.4f}")
print(f"Test Precision: {scores[2]:.4f}")
print(f"Test Recall: {scores[3]:.4f}")
print(f"Test F1: {scores[4]:.4f}")

# (Optional) Generate a classification report
y_true = test_generator.classes
y_pred_probs = model.predict(test_generator)
y_pred = np.argmax(y_pred_probs, axis=1)

print(classification_report(y_true, y_pred, target_names=test_generator.class_indices.keys()))

# Save the model
save_path = '/content/drive/MyDrive/VGG19/STFT_Folder/al-emadi_vgg19_standardized_STFT_1_test.keras'
model.save(save_path)
print(f"Model saved to: {save_path}")
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 10s 709ms/step - accuracy: 0.8534 - f1_score_metric: 0.1591 - loss: 0.4228 - precision: 0.8887 - recall: 0.8466
# Test Loss: 0.4962
# Test Accuracy: 0.8284
# Test Precision: 0.8686
# Test Recall: 0.8059
# Test F1: 0.1655
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 13s 767ms/step
#                  precision    recall  f1-score   support
#
# Emergency_alarm       0.91      0.91      0.91       124
#       Explosion       0.70      0.78      0.74        78
#       Gun_Shots       0.91      0.91      0.91        35
#             dog       0.81      0.90      0.85        51
#  glass_breaking       0.81      0.71      0.76        31
#    thunderstorm       0.77      0.71      0.74        58
#            wind       0.87      0.79      0.83        66
#
#        accuracy                           0.83       443
#       macro avg       0.83      0.82      0.82       443
#    weighted avg       0.83      0.83      0.83       443
#
# Model saved to: /content/drive/MyDrive/VGG19/STFT_Folder/al-emadi_vgg19_standardized_STFT_1_test.keras

# %%
################################################################################
# 12) MAKE PREDICTIONS & CONFUSION MATRIX
################################################################################

# Import confusion_matrix
from sklearn.metrics import confusion_matrix

predictions = model.predict(test_generator)
predicted_classes = np.argmax(predictions, axis=1)

true_classes = test_generator.classes
class_labels = list(test_generator.class_indices.keys())

conf_matrix = confusion_matrix(true_classes, predicted_classes)
print("\nConfusion Matrix:")
print(conf_matrix)

print("\nClassification Report:")
print(classification_report(true_classes, predicted_classes, target_names=class_labels))
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 13s 924ms/step
#
# Confusion Matrix:
# [[113   4   0   5   0   1   1]
#  [  7  61   0   2   4   4   0]
#  [  0   1  32   0   1   1   0]
#  [  2   1   0  46   0   2   0]
#  [  1   3   1   3  22   1   0]
#  [  0   8   2   0   0  41   7]
#  [  1   9   0   1   0   3  52]]
#
# Classification Report:
#                  precision    recall  f1-score   support
#
# Emergency_alarm       0.91      0.91      0.91       124
#       Explosion       0.70      0.78      0.74        78
#       Gun_Shots       0.91      0.91      0.91        35
#             dog       0.81      0.90      0.85        51
#  glass_breaking       0.81      0.71      0.76        31
#    thunderstorm       0.77      0.71      0.74        58
#            wind       0.87      0.79      0.83        66
#
#        accuracy                           0.83       443
#       macro avg       0.83      0.82      0.82       443
#    weighted avg       0.83      0.83      0.83       443

# %%
################################################################################
# 13) PER-CLASS ACCURACY
################################################################################

class_accuracy = {}
for i, lbl in enumerate(class_labels):
    correct_indices = np.where(true_classes == i)[0]
    correct_count = np.sum(predicted_classes[correct_indices] == i)
    total_count = len(correct_indices)
    if total_count > 0:
        class_accuracy[lbl] = correct_count / total_count
    else:
        class_accuracy[lbl] = 0.0

print("\nAccuracy for each class:")
for lbl in class_labels:
    print(f"{lbl}: {class_accuracy[lbl]:.4f}")
# Out:
# Accuracy for each class:
# Emergency_alarm: 0.9113
# Explosion: 0.7821
# Gun_Shots: 0.9143
# dog: 0.9020
# glass_breaking: 0.7097
# thunderstorm: 0.7069
# wind: 0.7879

# %%
################################################################################
# 14) OPTIONALLY: PLOT TRAINING CURVES
################################################################################

import pandas as pd # Import pandas for DataFrame

# Convert history to a DataFrame
history_df = pd.DataFrame(history.history)

plt.figure(figsize=(8,5))
plt.plot(history_df['loss'], label='Train Loss')
plt.plot(history_df['val_loss'], label='Val Loss', linestyle='--')
plt.title('Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

plt.figure(figsize=(8,5))
plt.plot(history_df['accuracy'], label='Train Accuracy')
plt.plot(history_df['val_accuracy'], label='Val Accuracy', linestyle='--')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix

# Suppose you already have predictions (predicted_classes),
# ground truth classes (true_classes), and class labels (class_labels).
true_classes = test_generator.classes
predicted_classes = np.argmax(predictions, axis=1)

class_labels = list(test_generator.class_indices.keys())

cm = confusion_matrix(true_classes, predicted_classes)

plt.figure(figsize=(10, 8))
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()

# Set tick labels (class names)
tick_marks = np.arange(len(class_labels))
plt.xticks(tick_marks, class_labels, rotation=45)
plt.yticks(tick_marks, class_labels)

# Annotate each cell with the count
threshold = cm.max() / 2
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        value = cm[i, j]
        plt.text(j, i, str(value),
                 ha="center", va="center",
                 color="white" if value > threshold else "black")

plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.tight_layout()  # Helps prevent label cutoff
plt.show()

# %%
import pandas as pd

# Train the model
history = model.fit(
    train_generator,
    epochs=100,
    validation_data=test_generator,
    callbacks=[early_stopping],
    shuffle=True
)

# Convert the training history to a DataFrame
df = pd.DataFrame(history.history)

# Save to CSV
csv_filename = '/content/drive/MyDrive/VGG19/MEL_Folder/training_metrics.csv'
df.to_csv(csv_filename, index=False)
print(f"Training metrics saved to {csv_filename}")

# Evaluate on test data
loss, accuracy, precision, recall, f1_score = model.evaluate(test_generator)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)
print("Test Precision:", precision)
print("Test Recall:", recall)
print("Test F1 Score:", f1_score)
# Out:
# Epoch 1/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 24s 696ms/step - accuracy: 0.8247 - f1_score_metric: 0.7792 - loss: 0.4585 - precision: 0.8644 - recall: 0.7848 - val_accuracy: 0.8155 - val_f1_score_metric: 0.1737 - val_loss: 0.5661 - val_precision: 0.8449 - val_recall: 0.7883
# Epoch 2/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 24s 685ms/step - accuracy: 0.8854 - f1_score_metric: 0.8341 - loss: 0.3593 - precision: 0.9102 - recall: 0.8468 - val_accuracy: 0.8134 - val_f1_score_metric: 0.1723 - val_loss: 0.5750 - val_precision: 0.8552 - val_recall: 0.7925
# Epoch 3/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 23s 671ms/step - accuracy: 0.8736 - f1_score_metric: 0.8201 - loss: 0.3894 - precision: 0.9103 - recall: 0.8268 - val_accuracy: 0.8365 - val_f1_score_metric: 0.1745 - val_loss: 0.5295 - val_precision: 0.8702 - val_recall: 0.8008
# Epoch 4/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 41s 673ms/step - accuracy: 0.8577 - f1_score_metric: 0.8127 - loss: 0.3819 - precision: 0.9000 - recall: 0.8145 - val_accuracy: 0.8155 - val_f1_score_metric: 0.1718 - val_loss: 0.5684 - val_precision: 0.8412 - val_recall: 0.7883
# Epoch 5/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 23s 667ms/step - accuracy: 0.8482 - f1_score_metric: 0.7843 - loss: 0.3753 - precision: 0.8767 - recall: 0.8193 - val_accuracy: 0.8176 - val_f1_score_metric: 0.1566 - val_loss: 0.5938 - val_precision: 0.8621 - val_recall: 0.7338
# Epoch 6/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 25s 709ms/step - accuracy: 0.8309 - f1_score_metric: 0.7957 - loss: 0.4512 - precision: 0.8683 - recall: 0.8022 - val_accuracy: 0.8260 - val_f1_score_metric: 0.1748 - val_loss: 0.5412 - val_precision: 0.8623 - val_recall: 0.8008
# Epoch 7/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 646ms/step - accuracy: 0.8779 - f1_score_metric: 0.8275 - loss: 0.3632 - precision: 0.9139 - recall: 0.8217 - val_accuracy: 0.8323 - val_f1_score_metric: 0.1745 - val_loss: 0.5525 - val_precision: 0.8584 - val_recall: 0.8008
# Epoch 8/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 23s 662ms/step - accuracy: 0.8716 - f1_score_metric: 0.8303 - loss: 0.3606 - precision: 0.9081 - recall: 0.8399 - val_accuracy: 0.8344 - val_f1_score_metric: 0.1713 - val_loss: 0.5563 - val_precision: 0.8565 - val_recall: 0.8008
# Epoch 9/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 23s 665ms/step - accuracy: 0.8683 - f1_score_metric: 0.8325 - loss: 0.3325 - precision: 0.9081 - recall: 0.8446 - val_accuracy: 0.8344 - val_f1_score_metric: 0.1569 - val_loss: 0.5912 - val_precision: 0.8772 - val_recall: 0.7338
# Epoch 10/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 41s 663ms/step - accuracy: 0.8700 - f1_score_metric: 0.8420 - loss: 0.3697 - precision: 0.9168 - recall: 0.8308 - val_accuracy: 0.7631 - val_f1_score_metric: 0.1536 - val_loss: 0.6258 - val_precision: 0.8488 - val_recall: 0.7296
# Epoch 11/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 23s 665ms/step - accuracy: 0.8542 - f1_score_metric: 0.8063 - loss: 0.3823 - precision: 0.9038 - recall: 0.8158 - val_accuracy: 0.8218 - val_f1_score_metric: 0.1651 - val_loss: 0.5961 - val_precision: 0.8507 - val_recall: 0.7883
# Epoch 12/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 23s 661ms/step - accuracy: 0.8732 - f1_score_metric: 0.8358 - loss: 0.3498 - precision: 0.8970 - recall: 0.8425 - val_accuracy: 0.8008 - val_f1_score_metric: 0.1711 - val_loss: 0.6102 - val_precision: 0.8176 - val_recall: 0.7799
# Epoch 13/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 645ms/step - accuracy: 0.8504 - f1_score_metric: 0.7877 - loss: 0.4187 - precision: 0.8746 - recall: 0.8150 - val_accuracy: 0.7925 - val_f1_score_metric: 0.1631 - val_loss: 0.6595 - val_precision: 0.8214 - val_recall: 0.7715
# Epoch 14/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 24s 681ms/step - accuracy: 0.8658 - f1_score_metric: 0.8337 - loss: 0.3822 - precision: 0.8889 - recall: 0.8382 - val_accuracy: 0.7191 - val_f1_score_metric: 0.1454 - val_loss: 0.7772 - val_precision: 0.7904 - val_recall: 0.6876
# Epoch 15/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 24s 676ms/step - accuracy: 0.8443 - f1_score_metric: 0.7771 - loss: 0.4031 - precision: 0.8845 - recall: 0.8034 - val_accuracy: 0.7505 - val_f1_score_metric: 0.1543 - val_loss: 0.6220 - val_precision: 0.8390 - val_recall: 0.7212
# Epoch 16/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 23s 674ms/step - accuracy: 0.8559 - f1_score_metric: 0.8323 - loss: 0.3609 - precision: 0.8991 - recall: 0.8273 - val_accuracy: 0.8071 - val_f1_score_metric: 0.1498 - val_loss: 0.5983 - val_precision: 0.8452 - val_recall: 0.7212
# Epoch 17/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 24s 688ms/step - accuracy: 0.9089 - f1_score_metric: 0.8621 - loss: 0.3003 - precision: 0.9298 - recall: 0.8750 - val_accuracy: 0.7799 - val_f1_score_metric: 0.1582 - val_loss: 0.5863 - val_precision: 0.8744 - val_recall: 0.7442
# Epoch 18/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 23s 646ms/step - accuracy: 0.8775 - f1_score_metric: 0.8436 - loss: 0.3333 - precision: 0.9148 - recall: 0.8320 - val_accuracy: 0.8155 - val_f1_score_metric: 0.1719 - val_loss: 0.5881 - val_precision: 0.8498 - val_recall: 0.7945
# Epoch 19/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 23s 663ms/step - accuracy: 0.8894 - f1_score_metric: 0.8398 - loss: 0.3084 - precision: 0.9192 - recall: 0.8594 - val_accuracy: 0.8176 - val_f1_score_metric: 0.1599 - val_loss: 0.5735 - val_precision: 0.8517 - val_recall: 0.7463
# Epoch 20/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 23s 666ms/step - accuracy: 0.8492 - f1_score_metric: 0.8041 - loss: 0.3971 - precision: 0.8933 - recall: 0.8168 - val_accuracy: 0.7631 - val_f1_score_metric: 0.1566 - val_loss: 0.5735 - val_precision: 0.8685 - val_recall: 0.7338
# Epoch 21/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 23s 656ms/step - accuracy: 0.8960 - f1_score_metric: 0.8340 - loss: 0.3247 - precision: 0.9247 - recall: 0.8383 - val_accuracy: 0.7589 - val_f1_score_metric: 0.1482 - val_loss: 0.6104 - val_precision: 0.8428 - val_recall: 0.7191
# Epoch 22/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 28s 797ms/step - accuracy: 0.8647 - f1_score_metric: 0.8326 - loss: 0.3691 - precision: 0.9178 - recall: 0.8204 - val_accuracy: 0.8176 - val_f1_score_metric: 0.1722 - val_loss: 0.5804 - val_precision: 0.8446 - val_recall: 0.7862
# Epoch 23/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 644ms/step - accuracy: 0.8728 - f1_score_metric: 0.8210 - loss: 0.3624 - precision: 0.9115 - recall: 0.8398 - val_accuracy: 0.8281 - val_f1_score_metric: 0.1559 - val_loss: 0.5529 - val_precision: 0.8701 - val_recall: 0.7442
# Epoch 24/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 23s 666ms/step - accuracy: 0.8874 - f1_score_metric: 0.8376 - loss: 0.3496 - precision: 0.9131 - recall: 0.8418 - val_accuracy: 0.8407 - val_f1_score_metric: 0.1750 - val_loss: 0.5478 - val_precision: 0.8568 - val_recall: 0.8155
# Epoch 25/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 23s 673ms/step - accuracy: 0.8633 - f1_score_metric: 0.8338 - loss: 0.3544 - precision: 0.9070 - recall: 0.8407 - val_accuracy: 0.8365 - val_f1_score_metric: 0.1707 - val_loss: 0.5607 - val_precision: 0.8623 - val_recall: 0.8008
# Epoch 26/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 23s 662ms/step - accuracy: 0.8751 - f1_score_metric: 0.8598 - loss: 0.3441 - precision: 0.9033 - recall: 0.8467 - val_accuracy: 0.7652 - val_f1_score_metric: 0.1461 - val_loss: 0.6453 - val_precision: 0.8050 - val_recall: 0.7358
# Epoch 27/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 22s 645ms/step - accuracy: 0.8915 - f1_score_metric: 0.8401 - loss: 0.3141 - precision: 0.9159 - recall: 0.8637 - val_accuracy: 0.7568 - val_f1_score_metric: 0.1460 - val_loss: 0.6387 - val_precision: 0.7848 - val_recall: 0.7338
# Epoch 28/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 23s 666ms/step - accuracy: 0.8754 - f1_score_metric: 0.8537 - loss: 0.3484 - precision: 0.9039 - recall: 0.8503 - val_accuracy: 0.8407 - val_f1_score_metric: 0.1581 - val_loss: 0.5610 - val_precision: 0.8652 - val_recall: 0.7400
# Epoch 29/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 25s 712ms/step - accuracy: 0.8884 - f1_score_metric: 0.8608 - loss: 0.3291 - precision: 0.9204 - recall: 0.8549 - val_accuracy: 0.8134 - val_f1_score_metric: 0.1717 - val_loss: 0.5913 - val_precision: 0.8523 - val_recall: 0.7862
# Epoch 30/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 24s 692ms/step - accuracy: 0.8838 - f1_score_metric: 0.8465 - loss: 0.3183 - precision: 0.9102 - recall: 0.8619 - val_accuracy: 0.8113 - val_f1_score_metric: 0.1578 - val_loss: 0.5954 - val_precision: 0.8475 - val_recall: 0.7338
# Epoch 31/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 27s 785ms/step - accuracy: 0.8627 - f1_score_metric: 0.8273 - loss: 0.3529 - precision: 0.9012 - recall: 0.8404 - val_accuracy: 0.7212 - val_f1_score_metric: 0.1478 - val_loss: 0.7632 - val_precision: 0.7456 - val_recall: 0.7065
# Epoch 32/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 23s 666ms/step - accuracy: 0.8709 - f1_score_metric: 0.8327 - loss: 0.3650 - precision: 0.8946 - recall: 0.8467 - val_accuracy: 0.7484 - val_f1_score_metric: 0.1491 - val_loss: 0.7003 - val_precision: 0.7831 - val_recall: 0.7191
# Epoch 33/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 23s 651ms/step - accuracy: 0.8783 - f1_score_metric: 0.8416 - loss: 0.3246 - precision: 0.9192 - recall: 0.8484 - val_accuracy: 0.8008 - val_f1_score_metric: 0.1532 - val_loss: 0.6276 - val_precision: 0.8437 - val_recall: 0.7128
# Training metrics saved to /content/drive/MyDrive/VGG19/MEL_Folder/training_metrics.csv
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 402ms/step - accuracy: 0.8395 - f1_score_metric: 0.1595 - loss: 0.4673 - precision: 0.8741 - recall: 0.8073
# Test Loss: 0.5295250415802002
# Test Accuracy: 0.8364779949188232
# Test Precision: 0.8701594471931458
# Test Recall: 0.8008385896682739
# Test F1 Score: 0.17450647056102753

# %%
import matplotlib.pyplot as plt

# Suppose your training run is stored in `history`
# after something like: history = model.fit(...)

# 1) Plot Training vs. Validation Loss
plt.figure(figsize=(12, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss', linestyle='--')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# 2) Plot Training vs. Validation Accuracy
# (Only if 'accuracy' and 'val_accuracy' are in your history)
plt.figure(figsize=(12, 5))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', linestyle='--')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras import backend as K
from tensorflow.keras.utils import register_keras_serializable

################################################################################
# 1) Define Your Custom F1 Metric (if used in training)
################################################################################

@register_keras_serializable()
def f1_score_metric(y_true, y_pred):
    # Round predictions to 0/1
    y_pred = tf.math.round(y_pred)

    tp = K.sum(K.cast(y_true * y_pred, 'float'), axis=0)
    fp = K.sum(K.cast((1 - y_true) * y_pred, 'float'), axis=0)
    fn = K.sum(K.cast(y_true * (1 - y_pred), 'float'), axis=0)

    precision = tp / (tp + fp + K.epsilon())
    recall    = tp / (tp + fn + K.epsilon())
    f1        = 2 * precision * recall / (precision + recall + K.epsilon())
    return K.mean(f1)

################################################################################
# 2) Model & Data Configuration
################################################################################

num_classes = 7
height = 128
width = 128
channels = 3
batch_size = 32

model_path = '/content/drive/MyDrive/VGG19/MEL_Folder/al-emadi_vgg19_standardized_Mel_1_test.keras'
test_dir   = '/content/drive/MyDrive/ASE_Dataset_Folder/Mel_Images_1_Sec/Test/Sounds'

################################################################################
# 3) Load the Model with Custom Metric
################################################################################

model = tf.keras.models.load_model(
    model_path,
    custom_objects={'f1_score_metric': f1_score_metric}
)

################################################################################
# 4) Create Test Data Generator
################################################################################

test_datagen = ImageDataGenerator()  # No rescale=1./255?  Include if needed
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(height, width),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)

################################################################################
# 5) Evaluate the Model
################################################################################

results = model.evaluate(test_generator)
print(f"Test Loss: {results[0]:.4f}")
print(f"Test Accuracy: {results[1]:.4f}")

# If more metrics exist, print them
if len(results) > 2:
    print("Additional Metrics:")
    for metric, value in zip(model.metrics_names[2:], results[2:]):
        print(f"{metric.capitalize()}: {value:.4f}")

################################################################################
# 6) Predictions & Confusion Matrix
################################################################################

predictions = model.predict(test_generator)
predicted_classes = np.argmax(predictions, axis=1)

true_classes = test_generator.classes
conf_matrix = confusion_matrix(true_classes, predicted_classes)

print("\nConfusion Matrix:")
print(conf_matrix)

# Get class labels
class_labels = list(test_generator.class_indices.keys())

################################################################################
# 7) Classification Report
################################################################################

print("\nClassification Report:")
print(classification_report(true_classes, predicted_classes, target_names=class_labels))

################################################################################
# 8) Per-Class Accuracy
################################################################################

class_accuracy = {}
for i, class_label in enumerate(class_labels):
    correct_indices = np.where(true_classes == i)[0]
    correct_predictions = np.sum(predicted_classes[correct_indices] == i)
    total_samples = len(correct_indices)
    if total_samples > 0:
        class_accuracy[class_label] = correct_predictions / total_samples
    else:
        class_accuracy[class_label] = 0.0

print("\nAccuracy for each class:")
for class_label in class_labels:
    print(f"{class_label}: {class_accuracy[class_label]:.4f}")
# Out:
# Found 477 images belonging to 7 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 10s 391ms/step - accuracy: 0.5350 - f1_score_metric: 0.0944 - loss: 106.5778 - precision: 0.5350 - recall: 0.5350
# Test Loss: 149.5158
# Test Accuracy: 0.4130
# Additional Metrics:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 8s 468ms/step
#
# Confusion Matrix:
# [[93  0  0  1 30  0  0]
#  [16  0  0  3 59  0  0]
#  [ 9  0  0  0 26  0  0]
#  [ 4  0  0 43  9  0  0]
#  [ 0  0  0  1 59  0  0]
#  [27  0  0  5 24  2  0]
#  [41  0  0  0 24  1  0]]
#
# Classification Report:
#                  precision    recall  f1-score   support
#
# Emergency_alarm       0.49      0.75      0.59       124
#       Explosion       0.00      0.00      0.00        78
#       Gun_Shots       0.00      0.00      0.00        35
#             dog       0.81      0.77      0.79        56
#  glass_breaking       0.26      0.98      0.41        60
#    thunderstorm       0.67      0.03      0.07        58
#            wind       0.00      0.00      0.00        66
#
#        accuracy                           0.41       477
#       macro avg       0.32      0.36      0.26       477
#    weighted avg       0.34      0.41      0.31       477
#
#
# Accuracy for each class:
# Emergency_alarm: 0.7500
# Explosion: 0.0000
# Gun_Shots: 0.0000
# dog: 0.7679
# glass_breaking: 0.9833
# thunderstorm: 0.0345
# wind: 0.0000
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix

# Suppose you already have predictions (predicted_classes),
# ground truth classes (true_classes), and class labels (class_labels).
true_classes = test_generator.classes
predicted_classes = np.argmax(predictions, axis=1)

class_labels = list(test_generator.class_indices.keys())

cm = confusion_matrix(true_classes, predicted_classes)

plt.figure(figsize=(10, 8))
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()

# Set tick labels (class names)
tick_marks = np.arange(len(class_labels))
plt.xticks(tick_marks, class_labels, rotation=45)
plt.yticks(tick_marks, class_labels)

# Annotate each cell with the count
threshold = cm.max() / 2
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        value = cm[i, j]
        plt.text(j, i, str(value),
                 ha="center", va="center",
                 color="white" if value > threshold else "black")

plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.tight_layout()  # Helps prevent label cutoff
plt.show()

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf
import numpy as np

# Load the pre-trained model
model_path = '/content/drive/MyDrive/VGG19/Mel_Folder/al-emadi_vgg19_standardized_Mel_1_test.keras'
model = tf.keras.models.load_model(model_path)

# Data dimensions
height = 128
n_fft = 2048
hop_length = 256
sr = 22050
T = 1

hop_size_sec = hop_length / sr
audio_length_samples = T * sr
width = 1 + int((audio_length_samples - n_fft) / hop_length)
channels = 3
batch_size = 32

# Configuration for prediction
predict_datagen = ImageDataGenerator()
predict_dir = '/content/drive/MyDrive/TEST'  # Update this path to your directory

predict_generator = predict_datagen.flow_from_directory(
    predict_dir,
    target_size=(height, width),
    batch_size=batch_size,
    class_mode=None,  # No labels are provided
    shuffle=False)  # Important for maintaining order

# Ensure the generator is not empty
if len(predict_generator) == 0:
    raise ValueError(f"Predict generator is empty. Check the directory: {predict_dir}, ensure images are in a subfolder and 'target_size' is correct.")

# Make predictions
predictions = model.predict(predict_generator)
predicted_classes = np.argmax(predictions, axis=1)

# Get filenames from the generator
filenames = predict_generator.filenames

# Assuming you have a mapping of class indices to class labels
class_labels = {0: "Emergency_alarm", 1: "Explosion", 2: "Gun_Shots"}  # Update as per your model classes

# Zip filenames with predicted classes and labels
predicted_labels = [class_labels[cls] for cls in predicted_classes]
results = zip(filenames, predicted_classes, predicted_labels)

# Print results
print("Filename, Predicted Class ID, Predicted Label:")
for filename, class_id, label in results:
    print(f"{filename}, {class_id}, {label}")
