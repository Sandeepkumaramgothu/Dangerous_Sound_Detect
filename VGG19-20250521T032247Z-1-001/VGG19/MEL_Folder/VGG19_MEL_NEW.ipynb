# %%
################################################################################
# 1) Mount Drive, Check GPU, and Check RAM
################################################################################

from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# Check GPU info
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if 'failed' in gpu_info:
    print('Not connected to a GPU')
else:
    print(gpu_info)
# Out:
# Sun Apr 13 19:06:04 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   53C    P8             11W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# Check RAM
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print(f'Your runtime has {ram_gb:.1f} gigabytes of available RAM\n')
if ram_gb < 20:
    print('Not using a high-RAM runtime.')
else:
    print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 54.8 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
################################################################################
# 2) Installs (if needed; adjust packages as necessary)
################################################################################

# !pip -qqq install pydub
# !pip -qqq install tensorboard
# !pip -qqq install visualkeras
# !pip -qqq install --upgrade keras
# !pip -qqq install --upgrade tensorflow
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 997.4/997.4 kB 50.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 46.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.9/644.9 MB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 108.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 111.7 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-text 2.18.1 requires tensorflow<2.19,>=2.18.0, but you have tensorflow 2.19.0 which is incompatible.
# tf-keras 2.18.0 requires tensorflow<2.19,>=2.18, but you have tensorflow 2.19.0 which is incompatible.
# tensorflow-decision-forests 1.11.0 requires tensorflow==2.18.0, but you have tensorflow 2.19.0 which is incompatible.

# %%
################################################################################
# 3) Imports
################################################################################

import os
import math
import numpy as np
import librosa
import json
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import pickle
import random

# Sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

# Audio
from IPython.display import Audio
from scipy.io import wavfile
import scipy
import soundfile as sf
from pydub import AudioSegment

# TensorFlow / Keras
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import plot_model
from tensorflow.keras import layers, models
from tensorflow.keras.layers import Flatten, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.applications.vgg19 import VGG19

# Visualization
import visualkeras

# %%
################################################################################
# 4) Define Base Directories
################################################################################

import os

base_dir = '/content/drive/MyDrive/ASE_Dataset_Folder'
#sound_dir = os.path.join(base_dir, 'Sound_1_Sec_5_Files')

image_dir = os.path.join(base_dir,  'Mel_Images_1_Sec')
train_dir = os.path.join(image_dir, 'Train/Sounds')
test_dir = os.path.join(image_dir, 'Test/Sounds')

# Check if the train_dir exists
if os.path.exists(image_dir):
  if os.path.exists(train_dir):
    if os.path.exists(test_dir):
      print(f"train_dir exists: {image_dir}")
  else:
    print(f"train_dir does not exist: {train_dir}")

#train_dir = r"/content/drive/MyDrive/ASE_Dataset_Folder/Images_1_Sec/Train"
#test_dir = r"/content/drive/MyDrive/ASE_Dataset_Folder/Images_1_Sec/Test"



# List files in the train directory
train_files = os.listdir(train_dir)
print(f"Files in train directory: {train_files}")  # Print all files
print(f"Number of files in train directory: {len(train_files)}")

# List files in the test directory
test_files = os.listdir(test_dir)
print(f"Files in test directory: {test_files}")  # Print all files
print(f"Number of files in test directory: {len(test_files)}")
# Out:
# train_dir exists: /content/drive/MyDrive/ASE_Dataset_Folder/Mel_Images_1_Sec
# Files in train directory: ['Explosion', 'Emergency_alarm', 'Gun_Shots', 'glass_breaking', 'thunderstorm', 'dog', 'wind', 'Earthquake', 'Flood', 'Tsunami', 'Volcanic Eruption', 'Dam Failure', 'Wildfire']
# Number of files in train directory: 13
# Files in test directory: ['Gun_Shots', 'Emergency_alarm', 'Explosion', 'dog', 'glass_breaking', 'thunderstorm', 'wind', 'Flood', 'Earthquake', 'Tsunami', 'Volcanic Eruption', 'Dam Failure', 'Wildfire']
# Number of files in test directory: 13

# %%
################################################################################
# 5) Data Generators
################################################################################

# You can adjust your augmentations here
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)
test_datagen = ImageDataGenerator(rescale=1./255)

batch_size = 32
height = 128
width = 128   # Typically you'd want your spectrogram images to have a consistent shape
channels = 3  # 3 if color images

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(height, width),
    batch_size=batch_size,
    class_mode='categorical'
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(height, width),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)

print(f"Found {train_generator.samples} images for training.")
print(f"Found {test_generator.samples} images for testing.")
# Out:
# Found 3015 images belonging to 13 classes.
# Found 1351 images belonging to 13 classes.
# Found 3015 images for training.
# Found 1351 images for testing.

# %%
################################################################################
# 7) Load Pretrained VGG19 (with Frozen Layers)
################################################################################

# Include top=False means we remove the final dense layers,
# so we can replace them for our own classification.
vgg = VGG19(
    input_shape=(height, width, channels),
    weights="imagenet",
    include_top=False
)

# Freeze pretrained layers
for layer in vgg.layers:
    layer.trainable = False

x = Flatten()(vgg.output)
prediction = Dense(train_generator.num_classes, activation='softmax')(x)

model = Model(inputs=vgg.input, outputs=prediction)
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 128, 128, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 128, 128, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 64, 64, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 64, 64, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 64, 64, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 32, 32, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 32, 32, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 32, 32, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 32, 32, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv4 (Conv2D)           │ (None, 32, 32, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 16, 16, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 16, 16, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 16, 16, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 16, 16, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv4 (Conv2D)           │ (None, 16, 16, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 8, 8, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 8, 8, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 8, 8, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 8, 8, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv4 (Conv2D)           │ (None, 8, 8, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 4, 4, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 8192)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 13)             │       106,509 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 20,130,893 (76.79 MB)
#  Trainable params: 106,509 (416.05 KB)
#  Non-trainable params: 20,024,384 (76.39 MB)

# %%
################################################################################
# 8) Visualize Model
################################################################################

plot_model(model, to_file='model_structure.png', show_shapes=True, show_layer_names=True)
visualkeras.layered_view(model, legend=True)  # Only works in certain environments
# Out:
# /usr/local/lib/python3.11/dist-packages/visualkeras/layered.py:86: UserWarning: The legend_text_spacing_offset parameter is deprecated and will be removed in a future release.
#   warnings.warn("The legend_text_spacing_offset parameter is deprecated and will be removed in a future release.")
# <PIL.Image.Image image mode=RGBA size=1539x721>

# %%
################################################################################
# 9) Compile the Model
################################################################################
# Import necessary metrics
from tensorflow.keras.metrics import Precision, Recall

# Assuming f1_score_metric is a custom function, ensure it's defined

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=[
        'accuracy',
        Precision(name='precision'),
        Recall(name='recall'),
        # If f1_score_metric is a function, call it like this:
        # f1_score_metric
        # Otherwise, if it's a metric from tf.keras.metrics, import and use as above.
    ]
)

# %%
################################################################################
# 10) Fit the Model (Single Training Loop)
################################################################################

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    mode="min",
    patience=30,
    restore_best_weights=True
)

epochs = 150  # Adjust as needed

history = model.fit(
    train_generator,
    epochs=epochs,
    validation_data=test_generator,
    callbacks=[early_stopping],
    shuffle=True
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3019s 32s/step - accuracy: 0.3796 - loss: 2.0116 - precision: 0.7798 - recall: 0.1364 - val_accuracy: 0.5848 - val_loss: 1.3162 - val_precision: 0.7635 - val_recall: 0.4493
# Epoch 2/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 56s 588ms/step - accuracy: 0.6077 - loss: 1.2981 - precision: 0.8068 - recall: 0.4139 - val_accuracy: 0.6454 - val_loss: 1.1651 - val_precision: 0.7846 - val_recall: 0.5448
# Epoch 3/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 583ms/step - accuracy: 0.6419 - loss: 1.1607 - precision: 0.8182 - recall: 0.4789 - val_accuracy: 0.6817 - val_loss: 1.0546 - val_precision: 0.8366 - val_recall: 0.5307
# Epoch 4/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 56s 588ms/step - accuracy: 0.6839 - loss: 0.9919 - precision: 0.8346 - recall: 0.5356 - val_accuracy: 0.6047 - val_loss: 1.1921 - val_precision: 0.7270 - val_recall: 0.5204
# Epoch 5/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 57s 598ms/step - accuracy: 0.6898 - loss: 0.9831 - precision: 0.8344 - recall: 0.5623 - val_accuracy: 0.6943 - val_loss: 0.9894 - val_precision: 0.8149 - val_recall: 0.6092
# Epoch 6/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 56s 590ms/step - accuracy: 0.7042 - loss: 0.9356 - precision: 0.8494 - recall: 0.5896 - val_accuracy: 0.7283 - val_loss: 0.9125 - val_precision: 0.8558 - val_recall: 0.5973
# Epoch 7/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 581ms/step - accuracy: 0.7138 - loss: 0.9130 - precision: 0.8461 - recall: 0.5892 - val_accuracy: 0.7158 - val_loss: 0.9302 - val_precision: 0.8101 - val_recall: 0.6188
# Epoch 8/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 56s 586ms/step - accuracy: 0.7225 - loss: 0.8888 - precision: 0.8611 - recall: 0.5971 - val_accuracy: 0.7165 - val_loss: 0.9064 - val_precision: 0.8116 - val_recall: 0.6440
# Epoch 9/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 56s 585ms/step - accuracy: 0.7380 - loss: 0.8099 - precision: 0.8612 - recall: 0.6410 - val_accuracy: 0.7476 - val_loss: 0.8346 - val_precision: 0.8393 - val_recall: 0.6610
# Epoch 10/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 56s 588ms/step - accuracy: 0.7275 - loss: 0.8733 - precision: 0.8395 - recall: 0.6143 - val_accuracy: 0.7543 - val_loss: 0.8155 - val_precision: 0.8303 - val_recall: 0.6736
# Epoch 11/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 583ms/step - accuracy: 0.7350 - loss: 0.8535 - precision: 0.8451 - recall: 0.6405 - val_accuracy: 0.7565 - val_loss: 0.8247 - val_precision: 0.8406 - val_recall: 0.6869
# Epoch 12/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 56s 585ms/step - accuracy: 0.7671 - loss: 0.7502 - precision: 0.8791 - recall: 0.6822 - val_accuracy: 0.7209 - val_loss: 0.8703 - val_precision: 0.8456 - val_recall: 0.6566
# Epoch 13/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 583ms/step - accuracy: 0.7342 - loss: 0.8305 - precision: 0.8445 - recall: 0.6522 - val_accuracy: 0.7476 - val_loss: 0.8375 - val_precision: 0.8362 - val_recall: 0.6950
# Epoch 14/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 580ms/step - accuracy: 0.7608 - loss: 0.7377 - precision: 0.8710 - recall: 0.6654 - val_accuracy: 0.7350 - val_loss: 0.8633 - val_precision: 0.8158 - val_recall: 0.6588
# Epoch 15/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 583ms/step - accuracy: 0.7709 - loss: 0.7299 - precision: 0.8658 - recall: 0.6922 - val_accuracy: 0.7572 - val_loss: 0.8118 - val_precision: 0.8524 - val_recall: 0.6669
# Epoch 16/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 579ms/step - accuracy: 0.7567 - loss: 0.7404 - precision: 0.8665 - recall: 0.6759 - val_accuracy: 0.7498 - val_loss: 0.7957 - val_precision: 0.8592 - val_recall: 0.6728
# Epoch 17/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 583ms/step - accuracy: 0.7738 - loss: 0.7045 - precision: 0.8797 - recall: 0.6808 - val_accuracy: 0.7572 - val_loss: 0.7944 - val_precision: 0.8518 - val_recall: 0.6765
# Epoch 18/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 584ms/step - accuracy: 0.7743 - loss: 0.6974 - precision: 0.8660 - recall: 0.6854 - val_accuracy: 0.7113 - val_loss: 0.8387 - val_precision: 0.8189 - val_recall: 0.6528
# Epoch 19/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 581ms/step - accuracy: 0.7770 - loss: 0.6886 - precision: 0.8766 - recall: 0.6931 - val_accuracy: 0.7550 - val_loss: 0.7884 - val_precision: 0.8414 - val_recall: 0.6832
# Epoch 20/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 580ms/step - accuracy: 0.7841 - loss: 0.6927 - precision: 0.8709 - recall: 0.7019 - val_accuracy: 0.7779 - val_loss: 0.7668 - val_precision: 0.8696 - val_recall: 0.6862
# Epoch 21/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 580ms/step - accuracy: 0.7795 - loss: 0.6971 - precision: 0.8635 - recall: 0.6841 - val_accuracy: 0.7831 - val_loss: 0.7517 - val_precision: 0.8729 - val_recall: 0.6862
# Epoch 22/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 582ms/step - accuracy: 0.7994 - loss: 0.6593 - precision: 0.8790 - recall: 0.7105 - val_accuracy: 0.7335 - val_loss: 0.8233 - val_precision: 0.8047 - val_recall: 0.6773
# Epoch 23/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 580ms/step - accuracy: 0.7801 - loss: 0.6808 - precision: 0.8729 - recall: 0.7136 - val_accuracy: 0.7387 - val_loss: 0.8037 - val_precision: 0.8414 - val_recall: 0.6832
# Epoch 24/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 56s 591ms/step - accuracy: 0.7820 - loss: 0.6818 - precision: 0.8762 - recall: 0.7027 - val_accuracy: 0.7572 - val_loss: 0.7976 - val_precision: 0.8278 - val_recall: 0.7150
# Epoch 25/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 583ms/step - accuracy: 0.7934 - loss: 0.6369 - precision: 0.8860 - recall: 0.7244 - val_accuracy: 0.7328 - val_loss: 0.8166 - val_precision: 0.8278 - val_recall: 0.6617
# Epoch 26/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 583ms/step - accuracy: 0.7833 - loss: 0.6482 - precision: 0.8761 - recall: 0.7189 - val_accuracy: 0.7609 - val_loss: 0.7981 - val_precision: 0.8492 - val_recall: 0.6751
# Epoch 27/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 56s 587ms/step - accuracy: 0.7957 - loss: 0.6549 - precision: 0.8857 - recall: 0.7218 - val_accuracy: 0.7557 - val_loss: 0.7868 - val_precision: 0.8543 - val_recall: 0.6684
# Epoch 28/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 56s 591ms/step - accuracy: 0.7891 - loss: 0.6605 - precision: 0.8797 - recall: 0.7082 - val_accuracy: 0.7816 - val_loss: 0.7439 - val_precision: 0.8497 - val_recall: 0.7283
# Epoch 29/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 56s 586ms/step - accuracy: 0.7807 - loss: 0.6551 - precision: 0.8654 - recall: 0.7212 - val_accuracy: 0.7631 - val_loss: 0.7897 - val_precision: 0.8609 - val_recall: 0.6736
# Epoch 30/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 582ms/step - accuracy: 0.7827 - loss: 0.6729 - precision: 0.8776 - recall: 0.7206 - val_accuracy: 0.7350 - val_loss: 0.8738 - val_precision: 0.7918 - val_recall: 0.6869
# Epoch 31/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 56s 591ms/step - accuracy: 0.7985 - loss: 0.6283 - precision: 0.8867 - recall: 0.7290 - val_accuracy: 0.7794 - val_loss: 0.7396 - val_precision: 0.8498 - val_recall: 0.7246
# Epoch 32/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 581ms/step - accuracy: 0.7940 - loss: 0.6539 - precision: 0.8706 - recall: 0.7375 - val_accuracy: 0.7328 - val_loss: 0.8364 - val_precision: 0.8256 - val_recall: 0.6728
# Epoch 33/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 56s 586ms/step - accuracy: 0.8052 - loss: 0.6124 - precision: 0.8830 - recall: 0.7374 - val_accuracy: 0.7587 - val_loss: 0.8154 - val_precision: 0.8492 - val_recall: 0.6921
# Epoch 34/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 56s 589ms/step - accuracy: 0.8002 - loss: 0.6223 - precision: 0.8834 - recall: 0.7382 - val_accuracy: 0.7580 - val_loss: 0.8131 - val_precision: 0.8219 - val_recall: 0.7106
# Epoch 35/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 56s 591ms/step - accuracy: 0.7862 - loss: 0.6535 - precision: 0.8715 - recall: 0.7155 - val_accuracy: 0.7483 - val_loss: 0.7558 - val_precision: 0.8571 - val_recall: 0.6973
# Epoch 36/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 56s 586ms/step - accuracy: 0.7874 - loss: 0.6717 - precision: 0.8685 - recall: 0.7273 - val_accuracy: 0.7402 - val_loss: 0.8484 - val_precision: 0.8433 - val_recall: 0.6891
# Epoch 37/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 56s 588ms/step - accuracy: 0.7933 - loss: 0.6228 - precision: 0.8752 - recall: 0.7280 - val_accuracy: 0.7269 - val_loss: 0.8745 - val_precision: 0.8000 - val_recall: 0.6662
# Epoch 38/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 56s 587ms/step - accuracy: 0.7916 - loss: 0.6030 - precision: 0.8801 - recall: 0.7331 - val_accuracy: 0.7691 - val_loss: 0.7630 - val_precision: 0.8322 - val_recall: 0.7195
# Epoch 39/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 583ms/step - accuracy: 0.8081 - loss: 0.5736 - precision: 0.8924 - recall: 0.7532 - val_accuracy: 0.7794 - val_loss: 0.7342 - val_precision: 0.8445 - val_recall: 0.7276
# Epoch 40/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 581ms/step - accuracy: 0.8168 - loss: 0.5582 - precision: 0.8815 - recall: 0.7507 - val_accuracy: 0.7787 - val_loss: 0.7788 - val_precision: 0.8411 - val_recall: 0.7365
# Epoch 41/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 577ms/step - accuracy: 0.7982 - loss: 0.6137 - precision: 0.8724 - recall: 0.7395 - val_accuracy: 0.7772 - val_loss: 0.7380 - val_precision: 0.8496 - val_recall: 0.7024
# Epoch 42/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 580ms/step - accuracy: 0.8215 - loss: 0.5618 - precision: 0.8866 - recall: 0.7621 - val_accuracy: 0.7646 - val_loss: 0.7651 - val_precision: 0.8410 - val_recall: 0.7202
# Epoch 43/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 577ms/step - accuracy: 0.8166 - loss: 0.5751 - precision: 0.8865 - recall: 0.7478 - val_accuracy: 0.7535 - val_loss: 0.8092 - val_precision: 0.8306 - val_recall: 0.6862
# Epoch 44/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 581ms/step - accuracy: 0.8173 - loss: 0.5775 - precision: 0.8860 - recall: 0.7517 - val_accuracy: 0.7446 - val_loss: 0.7750 - val_precision: 0.8387 - val_recall: 0.6891
# Epoch 45/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 576ms/step - accuracy: 0.8186 - loss: 0.5658 - precision: 0.8839 - recall: 0.7563 - val_accuracy: 0.7713 - val_loss: 0.7472 - val_precision: 0.8436 - val_recall: 0.7024
# Epoch 46/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 579ms/step - accuracy: 0.8152 - loss: 0.5499 - precision: 0.8899 - recall: 0.7646 - val_accuracy: 0.7802 - val_loss: 0.7616 - val_precision: 0.8492 - val_recall: 0.7254
# Epoch 47/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 579ms/step - accuracy: 0.8112 - loss: 0.5751 - precision: 0.8770 - recall: 0.7564 - val_accuracy: 0.7594 - val_loss: 0.7400 - val_precision: 0.8515 - val_recall: 0.7172
# Epoch 48/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 580ms/step - accuracy: 0.8232 - loss: 0.5434 - precision: 0.8910 - recall: 0.7618 - val_accuracy: 0.7831 - val_loss: 0.7207 - val_precision: 0.8429 - val_recall: 0.7424
# Epoch 49/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 584ms/step - accuracy: 0.8248 - loss: 0.5381 - precision: 0.8951 - recall: 0.7590 - val_accuracy: 0.7321 - val_loss: 0.8736 - val_precision: 0.7925 - val_recall: 0.6928
# Epoch 50/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 584ms/step - accuracy: 0.8161 - loss: 0.5671 - precision: 0.8893 - recall: 0.7535 - val_accuracy: 0.7883 - val_loss: 0.7445 - val_precision: 0.8626 - val_recall: 0.7298
# Epoch 51/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 584ms/step - accuracy: 0.8213 - loss: 0.5817 - precision: 0.8853 - recall: 0.7619 - val_accuracy: 0.7839 - val_loss: 0.7354 - val_precision: 0.8632 - val_recall: 0.7195
# Epoch 52/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 586ms/step - accuracy: 0.8094 - loss: 0.5791 - precision: 0.8874 - recall: 0.7496 - val_accuracy: 0.7831 - val_loss: 0.7350 - val_precision: 0.8566 - val_recall: 0.7343
# Epoch 53/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 584ms/step - accuracy: 0.8237 - loss: 0.5306 - precision: 0.9005 - recall: 0.7677 - val_accuracy: 0.7528 - val_loss: 0.8023 - val_precision: 0.8388 - val_recall: 0.7010
# Epoch 54/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 581ms/step - accuracy: 0.8196 - loss: 0.5384 - precision: 0.8941 - recall: 0.7713 - val_accuracy: 0.7691 - val_loss: 0.7699 - val_precision: 0.8280 - val_recall: 0.7269
# Epoch 55/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 56s 587ms/step - accuracy: 0.8165 - loss: 0.5483 - precision: 0.8870 - recall: 0.7635 - val_accuracy: 0.7550 - val_loss: 0.7781 - val_precision: 0.8489 - val_recall: 0.6943
# Epoch 56/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 56s 586ms/step - accuracy: 0.8242 - loss: 0.5478 - precision: 0.8935 - recall: 0.7595 - val_accuracy: 0.7705 - val_loss: 0.7260 - val_precision: 0.8717 - val_recall: 0.7195
# Epoch 57/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 581ms/step - accuracy: 0.8211 - loss: 0.5470 - precision: 0.8948 - recall: 0.7741 - val_accuracy: 0.7691 - val_loss: 0.7395 - val_precision: 0.8600 - val_recall: 0.7232
# Epoch 58/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 574ms/step - accuracy: 0.8359 - loss: 0.5046 - precision: 0.9033 - recall: 0.7824 - val_accuracy: 0.7742 - val_loss: 0.7324 - val_precision: 0.8772 - val_recall: 0.7246
# Epoch 59/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 577ms/step - accuracy: 0.8165 - loss: 0.5321 - precision: 0.8896 - recall: 0.7638 - val_accuracy: 0.7853 - val_loss: 0.7292 - val_precision: 0.8418 - val_recall: 0.7446
# Epoch 60/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 578ms/step - accuracy: 0.8223 - loss: 0.5819 - precision: 0.8802 - recall: 0.7586 - val_accuracy: 0.7498 - val_loss: 0.8314 - val_precision: 0.8047 - val_recall: 0.6862
# Epoch 61/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 575ms/step - accuracy: 0.8339 - loss: 0.5216 - precision: 0.8982 - recall: 0.7738 - val_accuracy: 0.7890 - val_loss: 0.6782 - val_precision: 0.8745 - val_recall: 0.7372
# Epoch 62/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 581ms/step - accuracy: 0.8152 - loss: 0.5511 - precision: 0.8895 - recall: 0.7667 - val_accuracy: 0.7535 - val_loss: 0.7539 - val_precision: 0.8463 - val_recall: 0.7010
# Epoch 63/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 577ms/step - accuracy: 0.8296 - loss: 0.5237 - precision: 0.8929 - recall: 0.7744 - val_accuracy: 0.8113 - val_loss: 0.6931 - val_precision: 0.8864 - val_recall: 0.7395
# Epoch 64/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 579ms/step - accuracy: 0.8294 - loss: 0.5477 - precision: 0.8867 - recall: 0.7763 - val_accuracy: 0.8001 - val_loss: 0.7081 - val_precision: 0.8645 - val_recall: 0.7557
# Epoch 65/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 580ms/step - accuracy: 0.8181 - loss: 0.6049 - precision: 0.8719 - recall: 0.7703 - val_accuracy: 0.8135 - val_loss: 0.6654 - val_precision: 0.8823 - val_recall: 0.7491
# Epoch 66/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 582ms/step - accuracy: 0.8328 - loss: 0.5113 - precision: 0.8954 - recall: 0.7760 - val_accuracy: 0.7624 - val_loss: 0.8270 - val_precision: 0.8180 - val_recall: 0.7283
# Epoch 67/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 579ms/step - accuracy: 0.8368 - loss: 0.5434 - precision: 0.8884 - recall: 0.7876 - val_accuracy: 0.7853 - val_loss: 0.7458 - val_precision: 0.8444 - val_recall: 0.7269
# Epoch 68/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 579ms/step - accuracy: 0.8286 - loss: 0.5239 - precision: 0.8933 - recall: 0.7759 - val_accuracy: 0.7987 - val_loss: 0.6792 - val_precision: 0.8650 - val_recall: 0.7543
# Epoch 69/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 576ms/step - accuracy: 0.8268 - loss: 0.5258 - precision: 0.8933 - recall: 0.7689 - val_accuracy: 0.7979 - val_loss: 0.6882 - val_precision: 0.8538 - val_recall: 0.7609
# Epoch 70/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 576ms/step - accuracy: 0.8298 - loss: 0.5132 - precision: 0.8929 - recall: 0.7887 - val_accuracy: 0.7824 - val_loss: 0.7077 - val_precision: 0.8565 - val_recall: 0.7113
# Epoch 71/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 577ms/step - accuracy: 0.8355 - loss: 0.5033 - precision: 0.8917 - recall: 0.7772 - val_accuracy: 0.7950 - val_loss: 0.7265 - val_precision: 0.8475 - val_recall: 0.7402
# Epoch 72/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 578ms/step - accuracy: 0.8383 - loss: 0.5143 - precision: 0.8937 - recall: 0.7878 - val_accuracy: 0.7802 - val_loss: 0.7360 - val_precision: 0.8358 - val_recall: 0.7461
# Epoch 73/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 578ms/step - accuracy: 0.8336 - loss: 0.5122 - precision: 0.8956 - recall: 0.7839 - val_accuracy: 0.7883 - val_loss: 0.7357 - val_precision: 0.8486 - val_recall: 0.7424
# Epoch 74/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 581ms/step - accuracy: 0.8314 - loss: 0.5602 - precision: 0.8836 - recall: 0.7841 - val_accuracy: 0.8031 - val_loss: 0.6975 - val_precision: 0.8710 - val_recall: 0.7395
# Epoch 75/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 575ms/step - accuracy: 0.8378 - loss: 0.4799 - precision: 0.8981 - recall: 0.7834 - val_accuracy: 0.7927 - val_loss: 0.6938 - val_precision: 0.8674 - val_recall: 0.7313
# Epoch 76/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 577ms/step - accuracy: 0.8316 - loss: 0.5145 - precision: 0.8966 - recall: 0.7790 - val_accuracy: 0.7809 - val_loss: 0.7548 - val_precision: 0.8414 - val_recall: 0.7187
# Epoch 77/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 578ms/step - accuracy: 0.8378 - loss: 0.4858 - precision: 0.8990 - recall: 0.7931 - val_accuracy: 0.7661 - val_loss: 0.7418 - val_precision: 0.8588 - val_recall: 0.7246
# Epoch 78/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 577ms/step - accuracy: 0.8366 - loss: 0.5083 - precision: 0.8951 - recall: 0.7869 - val_accuracy: 0.7913 - val_loss: 0.6868 - val_precision: 0.8726 - val_recall: 0.7298
# Epoch 79/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 578ms/step - accuracy: 0.8390 - loss: 0.4754 - precision: 0.8913 - recall: 0.7937 - val_accuracy: 0.7224 - val_loss: 0.8799 - val_precision: 0.8082 - val_recall: 0.6832
# Epoch 80/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 56s 588ms/step - accuracy: 0.8290 - loss: 0.5133 - precision: 0.8902 - recall: 0.7811 - val_accuracy: 0.8016 - val_loss: 0.7080 - val_precision: 0.8610 - val_recall: 0.7380
# Epoch 81/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 585ms/step - accuracy: 0.8320 - loss: 0.5226 - precision: 0.8930 - recall: 0.7838 - val_accuracy: 0.8075 - val_loss: 0.6915 - val_precision: 0.8816 - val_recall: 0.7439
# Epoch 82/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 578ms/step - accuracy: 0.8288 - loss: 0.5182 - precision: 0.8876 - recall: 0.7742 - val_accuracy: 0.7750 - val_loss: 0.7775 - val_precision: 0.8249 - val_recall: 0.7395
# Epoch 83/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 582ms/step - accuracy: 0.8208 - loss: 0.5395 - precision: 0.8815 - recall: 0.7645 - val_accuracy: 0.7587 - val_loss: 0.7946 - val_precision: 0.8375 - val_recall: 0.7135
# Epoch 84/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 583ms/step - accuracy: 0.8329 - loss: 0.4998 - precision: 0.8906 - recall: 0.7884 - val_accuracy: 0.8009 - val_loss: 0.6816 - val_precision: 0.8685 - val_recall: 0.7432
# Epoch 85/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 583ms/step - accuracy: 0.8356 - loss: 0.5098 - precision: 0.8919 - recall: 0.7876 - val_accuracy: 0.7580 - val_loss: 0.7952 - val_precision: 0.8266 - val_recall: 0.7165
# Epoch 86/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 581ms/step - accuracy: 0.8281 - loss: 0.4870 - precision: 0.8903 - recall: 0.7850 - val_accuracy: 0.8068 - val_loss: 0.6744 - val_precision: 0.8642 - val_recall: 0.7491
# Epoch 87/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 56s 585ms/step - accuracy: 0.8330 - loss: 0.5055 - precision: 0.8828 - recall: 0.7910 - val_accuracy: 0.7964 - val_loss: 0.6900 - val_precision: 0.8551 - val_recall: 0.7646
# Epoch 88/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 56s 587ms/step - accuracy: 0.8550 - loss: 0.4686 - precision: 0.9004 - recall: 0.8078 - val_accuracy: 0.7624 - val_loss: 0.7720 - val_precision: 0.8478 - val_recall: 0.7254
# Epoch 89/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 585ms/step - accuracy: 0.8368 - loss: 0.4909 - precision: 0.9016 - recall: 0.7934 - val_accuracy: 0.7713 - val_loss: 0.7796 - val_precision: 0.8258 - val_recall: 0.7158
# Epoch 90/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 582ms/step - accuracy: 0.8534 - loss: 0.4593 - precision: 0.9129 - recall: 0.8098 - val_accuracy: 0.8001 - val_loss: 0.6925 - val_precision: 0.8555 - val_recall: 0.7365
# Epoch 91/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 576ms/step - accuracy: 0.8373 - loss: 0.4653 - precision: 0.8956 - recall: 0.7908 - val_accuracy: 0.7550 - val_loss: 0.7774 - val_precision: 0.8463 - val_recall: 0.7254
# Epoch 92/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 577ms/step - accuracy: 0.8484 - loss: 0.4753 - precision: 0.9107 - recall: 0.8035 - val_accuracy: 0.7779 - val_loss: 0.7033 - val_precision: 0.8737 - val_recall: 0.7321
# Epoch 93/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 579ms/step - accuracy: 0.8306 - loss: 0.5093 - precision: 0.8836 - recall: 0.7867 - val_accuracy: 0.7824 - val_loss: 0.6835 - val_precision: 0.8776 - val_recall: 0.7483
# Epoch 94/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 583ms/step - accuracy: 0.8185 - loss: 0.5293 - precision: 0.8867 - recall: 0.7698 - val_accuracy: 0.7698 - val_loss: 0.7957 - val_precision: 0.8300 - val_recall: 0.7298
# Epoch 95/150
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 55s 580ms/step - accuracy: 0.8466 - loss: 0.4739 - precision: 0.8986 - recall: 0.8062 - val_accuracy: 0.7920 - val_loss: 0.7180 - val_precision: 0.8687 - val_recall: 0.7543

# %%
################################################################################
# 11) Evaluate & Save
################################################################################

# Evaluate on the test set
scores = model.evaluate(test_generator, verbose=1)
print(f"Test Loss: {scores[0]:.4f}")
print(f"Test Accuracy: {scores[1]:.4f}")
print(f"Test Precision: {scores[2]:.4f}")
print(f"Test Recall: {scores[3]:.4f}")


# (Optional) Generate a classification report
y_true = test_generator.classes
y_pred_probs = model.predict(test_generator)
y_pred = np.argmax(y_pred_probs, axis=1)

print(classification_report(y_true, y_pred, target_names=test_generator.class_indices.keys()))

# Save the model
save_path = '/content/drive/MyDrive/VGG19/MEL_Folder/al-emadi_vgg19_MEL_new.keras'
model.save(save_path)
print(f"Model saved to: {save_path}")
# Out:
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 14s 328ms/step - accuracy: 0.7718 - loss: 0.8235 - precision: 0.8559 - recall: 0.7214
# Test Loss: 0.6654
# Test Accuracy: 0.8135
# Test Precision: 0.8823
# Test Recall: 0.7491
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 15s 333ms/step
#                    precision    recall  f1-score   support
#
#       Dam Failure       0.50      0.08      0.13        13
#        Earthquake       0.72      0.83      0.77       185
#   Emergency_alarm       0.95      0.89      0.92       124
#         Explosion       0.67      0.44      0.53        78
#             Flood       0.77      0.88      0.82        76
#         Gun_Shots       1.00      0.91      0.96        35
#           Tsunami       0.65      0.69      0.67        89
# Volcanic Eruption       0.76      0.58      0.66       111
#          Wildfire       0.95      0.98      0.97       400
#               dog       0.98      0.77      0.86        56
#    glass_breaking       0.68      0.90      0.78        60
#      thunderstorm       0.61      0.62      0.62        58
#              wind       0.67      0.74      0.71        66
#
#          accuracy                           0.81      1351
#         macro avg       0.76      0.72      0.72      1351
#      weighted avg       0.81      0.81      0.81      1351
#
# Model saved to: /content/drive/MyDrive/VGG19/MEL_Folder/al-emadi_vgg19_MEL_new.keras

# %%
################################################################################
# 12) MAKE PREDICTIONS & CONFUSION MATRIX
################################################################################

# Import confusion_matrix
from sklearn.metrics import confusion_matrix

predictions = model.predict(test_generator)
predicted_classes = np.argmax(predictions, axis=1)

true_classes = test_generator.classes
class_labels = list(test_generator.class_indices.keys())

conf_matrix = confusion_matrix(true_classes, predicted_classes)
print("\nConfusion Matrix:")
print(conf_matrix)

print("\nClassification Report:")
print(classification_report(true_classes, predicted_classes, target_names=class_labels))
# Out:
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 14s 325ms/step
#
# Confusion Matrix:
# [[  1   4   0   1   2   0   2   0   3   0   0   0   0]
#  [  0 154   0   3   1   0   6   5   3   0   5   5   3]
#  [  0   2 110   2   0   0   1   0   0   0   3   2   4]
#  [  0  11   4  34   5   0   1   4   5   0   5   6   3]
#  [  0   1   0   0  67   0   3   0   0   0   5   0   0]
#  [  0   0   0   2   0  32   0   0   1   0   0   0   0]
#  [  0   3   0   1   5   0  61   6   3   0   1   3   6]
#  [  0  20   0   3   2   0  14  64   0   0   1   5   2]
#  [  0   3   0   0   0   0   1   0 394   0   0   1   1]
#  [  0   2   2   0   0   0   0   1   0  43   5   1   2]
#  [  1   2   0   2   1   0   0   0   0   0  54   0   0]
#  [  0  11   0   0   1   0   2   3   1   1   0  36   3]
#  [  0   2   0   3   3   0   3   1   5   0   0   0  49]]
#
# Classification Report:
#                    precision    recall  f1-score   support
#
#       Dam Failure       0.50      0.08      0.13        13
#        Earthquake       0.72      0.83      0.77       185
#   Emergency_alarm       0.95      0.89      0.92       124
#         Explosion       0.67      0.44      0.53        78
#             Flood       0.77      0.88      0.82        76
#         Gun_Shots       1.00      0.91      0.96        35
#           Tsunami       0.65      0.69      0.67        89
# Volcanic Eruption       0.76      0.58      0.66       111
#          Wildfire       0.95      0.98      0.97       400
#               dog       0.98      0.77      0.86        56
#    glass_breaking       0.68      0.90      0.78        60
#      thunderstorm       0.61      0.62      0.62        58
#              wind       0.67      0.74      0.71        66
#
#          accuracy                           0.81      1351
#         macro avg       0.76      0.72      0.72      1351
#      weighted avg       0.81      0.81      0.81      1351

# %%
################################################################################
# 12) MAKE PREDICTIONS & CONFUSION MATRIX (with Visualizations)
################################################################################

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report, f1_score

# Make predictions
predictions = model.predict(test_generator)
predicted_classes = np.argmax(predictions, axis=1)

# True class indices and labels
true_classes = test_generator.classes
class_labels = list(test_generator.class_indices.keys())

# Confusion Matrix
conf_matrix = confusion_matrix(true_classes, predicted_classes)

# Plot Confusion Matrix Heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.title('Confusion Matrix Heatmap')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.tight_layout()
plt.show()

# Classification Report
print("\nClassification Report:")
report = classification_report(true_classes, predicted_classes, target_names=class_labels, output_dict=True)
report_df = pd.DataFrame(report).transpose()
report_df = report_df.iloc[:-3, :]  # remove accuracy, macro avg, weighted avg
print(report_df)

# Plot precision, recall, f1-score per class
report_df[['precision', 'recall', 'f1-score']].plot(kind='bar', figsize=(14, 6))
plt.title('Classification Metrics per Class')
plt.xlabel('Class')
plt.ylabel('Score')
plt.ylim(0, 1.05)
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# Per-Class Accuracy Calculation
class_accuracy = {}
for i, label in enumerate(class_labels):
    class_indices = np.where(true_classes == i)[0]
    correct_preds = np.sum(predicted_classes[class_indices] == i)
    class_accuracy[label] = correct_preds / len(class_indices) if len(class_indices) > 0 else 0.0

# Plot Per-Class Accuracy
plt.figure(figsize=(12, 6))
plt.bar(class_accuracy.keys(), class_accuracy.values(), color='skyblue')
plt.title('Per-Class Accuracy')
plt.xlabel('Class')
plt.ylabel('Accuracy')
plt.xticks(rotation=45)
plt.ylim(0, 1.05)
plt.grid(True)
plt.tight_layout()
plt.show()

################################################################################
# 13) Plot Training & Validation Accuracy Over Epochs
################################################################################

if 'history' in locals():
    plt.figure(figsize=(10, 6))
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Model Accuracy Over Epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()
else:
    print("Training history not available. Make sure you trained the model with history = model.fit(...)")
# Out:
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 14s 324ms/step
# Classification Report:
#                    precision    recall  f1-score  support
# Dam Failure         0.500000  0.076923  0.133333     13.0
# Earthquake          0.716279  0.832432  0.770000    185.0
# Emergency_alarm     0.948276  0.887097  0.916667    124.0
# Explosion           0.666667  0.435897  0.527132     78.0
# Flood               0.770115  0.881579  0.822086     76.0
# Gun_Shots           1.000000  0.914286  0.955224     35.0
# Tsunami             0.648936  0.685393  0.666667     89.0
# Volcanic Eruption   0.761905  0.576577  0.656410    111.0
# Wildfire            0.949398  0.985000  0.966871    400.0
# dog                 0.977273  0.767857  0.860000     56.0
# glass_breaking      0.683544  0.900000  0.776978     60.0
# thunderstorm        0.610169  0.620690  0.615385     58.0
# wind                0.671233  0.742424  0.705036     66.0
